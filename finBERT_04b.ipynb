# %% [markdown]
# <a href="https://colab.research.google.com/github/sarilacivert/three/blob/main/finBERT_04b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Financial News Text Classification Using FinBERT With Pytorch**

# %%
#pip install transformers

# %%
import warnings
warnings.filterwarnings('ignore') # to avoid warnings

#Standard Libraries
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt


##Sklearn Libraries
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

#Transformer Libraries
from transformers import BertTokenizer,  AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup

#Pytorch Libraries
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset

# %%
def show_headline_distribution(sequence_lengths, figsize = (15,8)):
    
    # Get the percentage of reviews with length > 512
    len_512_plus = [rev_len for rev_len in sequence_lengths if rev_len > 512]
    percent = (len(len_512_plus)/len(sequence_lengths))*100
    
    print("Maximum Sequence Length is {}".format(max(sequence_lengths)))
    
    # Configure the plot size
    plt.figure(figsize = figsize)

    sns.set(style='darkgrid')
    
    # Increase information on the figure
    sns.set(font_scale=1.3)
    
    # Plot the result
    sns.distplot(sequence_lengths, kde = False, rug = False)
    plt.title('Headlines Lengths Distribution')
    plt.xlabel('Headlines Length')
    plt.ylabel('Number of Headlines')

# %%
financial_data = pd.read_csv("/content/sample_data/news2.csv", 
                             encoding = 'ISO-8859-1', 
                             names=['sentiment', 'headline'])

# %%
financial_data.head()
# Out:
#   sentiment                                           headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
financial_data.shape
# Out:
# (4846, 2)

# %%
financial_data.sentiment.value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: sentiment, dtype: int64

# %%
def show_random_headlines(total_number, df):
    
    # Get the random number of reviews
    n_reviews = df.sample(total_number)
    
    # Print each one of the reviews
    for val in list(n_reviews.index):
        print("Reviews #°{}".format(val))
        print(" - Sentiment: {}".format(df.iloc[val]["sentiment"]))
        print(" - News Headline: {}".format(df.iloc[val]["headline"]))
        print("")

# %%
# Show 3 random headlines
show_random_headlines(5, financial_data)
# Out:
# Reviews #°886
#  - Sentiment: neutral
#  - News Headline: Stora Enso will record a capital gain of EUR 33 million as a non-recurring financial item in its fourth quarter 2006 results .
#
# Reviews #°3245
#  - Sentiment: neutral
#  - News Headline: The fair value of CapMan Plc 's own investments on 30 September 2008 amounted to MEUR 59.8 .
#
# Reviews #°522
#  - Sentiment: neutral
#  - News Headline: The order consists of capacity expansion , maintenance services and new charging functionality , the company said .
#
# Reviews #°4342
#  - Sentiment: neutral
#  - News Headline: The difference can be explained by the fact that two shipping companies have stopped operating in the Gulf of Finland .
#
# Reviews #°4366
#  - Sentiment: neutral
#  - News Headline: Viking Line has also been forced to alter its timetable so that ferries traveling from Stockholm to Helsinki , Finland , only depart at night .

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Configure the plot size
plt.figure(figsize = (15,8))

sns.set(style='darkgrid')
    
# Increase information on the figure
sns.set(font_scale=1.3)
sns.countplot(x='sentiment', data = financial_data)
plt.title('News Sentiment Distribution')
plt.xlabel('News Polarity')
plt.ylabel('Number of News')
# Out:
# Text(0, 0.5, 'Number of News')

# %%
def get_headlines_len(df):
    
    headlines_sequence_lengths = []
    
    print("Encoding in progress...")
    for headline in tqdm(df.headline):
        encoded_headline = finbert_tokenizer.encode(headline, 
                                         add_special_tokens = True)
        
        # record the length of the encoded review
        headlines_sequence_lengths.append(len(encoded_headline))
    print("End of Task.")
    
    return headlines_sequence_lengths

# %% [markdown]
# **Data Preparation Label Encoding**

# %%
def encode_sentiments_values(df):
    
    possible_sentiments = df.sentiment.unique()
    sentiment_dict = {}
    
    for index, possible_sentiment in enumerate(possible_sentiments):
        sentiment_dict[possible_sentiment] = index
    
    # Encode all the sentiment values
    df['label'] = df.sentiment.replace(sentiment_dict)
    
    return df, sentiment_dict

# %%
financial_data.head()
# Out:
#   sentiment                                           headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
# Encode the sentiment column
financial_data, sentiment_dict = encode_sentiments_values(financial_data)

financial_data.head()
# Out:
#   sentiment                                           headline  label
# 0   neutral  According to Gran , the company has no plans t...      0
# 1   neutral  Technopolis plans to develop in stages an area...      0
# 2  negative  The international electronic industry company ...      1
# 3  positive  With the new production plant the company woul...      2
# 4  positive  According to the company 's updated strategy f...      2

# %% [markdown]
# **Data Preparation Data Creation**

# %%
# Create training and validation data
X_train, X_val, y_train, y_val = train_test_split(financial_data.index.values, 
                                                  financial_data.label.values, 
                                                  test_size = 0.15, 
                                                  random_state = 2022,
                                                  stratify = financial_data.label.values)

# %%
# Create the data type columns
financial_data.loc[X_train, 'data_type'] = 'train'
financial_data.loc[X_val, 'data_type'] = 'val'

# Visualize the number of sentiment occurence on each type of data
financial_data.groupby(['sentiment', 'label', 'data_type']).count()
# Out:
#                            headline
# sentiment label data_type
# negative  1     train           513
#                 val              91
# neutral   0     train          2447
#                 val             432
# positive  2     train          1159
#                 val             204

# %% [markdown]
# **Data Preparation Tokenizer**

# %%
# Get the FinBERT Tokenizer
finbert_tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert", 
                                          do_lower_case=True)

# Encode the Training and Validation Data
encoded_data_train = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='train'].headline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)

encoded_data_val = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='val'].headline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(financial_data[financial_data.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
sentiments_val = torch.tensor(financial_data[financial_data.data_type=='val'].label.values)


dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, sentiments_val)
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
len(sentiment_dict)
# Out:
# 3

# %% [markdown]
# **Set Up the Pretrained Model**

# %%
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)
# Out:
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]

# %%
headlines_sequence_lengths = get_headlines_len(financial_data)
# Out:
# Encoding in progress...
# 100%|██████████| 4846/4846 [00:03<00:00, 1510.18it/s]
# End of Task.

# %%
# Show the reviews distribution and the overall implementation of this function

show_headline_distribution(headlines_sequence_lengths)
# Out:
# Maximum Sequence Length is 150

# %% [markdown]
# **Generate Data Loaders**

# %%
batch_size = 5

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %% [markdown]
# **Prepare Optimizer and Scheduler**

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)

epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %% [markdown]
# **Performance Metric Definitions**

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in sentiment_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %% [markdown]
# **Training Loop Generation**

# %%
# %%time
seed_val = 2022
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)


def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals


for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_finBERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/824 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/824 [00:01<?, ?it/s, training_loss=1.019]
# Epoch 1:   0%|          | 1/824 [00:01<17:03,  1.24s/it, training_loss=1.019]
# Epoch 1:   0%|          | 1/824 [00:02<17:03,  1.24s/it, training_loss=0.803]
# Epoch 1:   0%|          | 2/824 [00:02<17:38,  1.29s/it, training_loss=0.803]
# Epoch 1:   0%|          | 2/824 [00:03<17:38,  1.29s/it, training_loss=0.530]
# Epoch 1:   0%|          | 3/824 [00:03<17:03,  1.25s/it, training_loss=0.530]
# Epoch 1:   0%|          | 3/824 [00:04<17:03,  1.25s/it, training_loss=0.441]
# Epoch 1:   0%|          | 4/824 [00:04<16:40,  1.22s/it, training_loss=0.441]
# Epoch 1:   0%|          | 4/824 [00:06<16:40,  1.22s/it, training_loss=0.391]
# Epoch 1:   1%|          | 5/824 [00:06<16:38,  1.22s/it, training_loss=0.391]
# Epoch 1:   1%|          | 5/824 [00:07<16:38,  1.22s/it, training_loss=0.836]
# Epoch 1:   1%|          | 6/824 [00:07<16:20,  1.20s/it, training_loss=0.836]
# Epoch 1:   1%|          | 6/824 [00:08<16:20,  1.20s/it, training_loss=0.435]
# Epoch 1:   1%|          | 7/824 [00:08<16:15,  1.19s/it, training_loss=0.435]
# Epoch 1:   1%|          | 7/824 [00:09<16:15,  1.19s/it, training_loss=0.319]
# Epoch 1:   1%|          | 8/824 [00:09<16:09,  1.19s/it, training_loss=0.319]
# Epoch 1:   1%|          | 8/824 [00:10<16:09,  1.19s/it, training_loss=0.403]
# Epoch 1:   1%|          | 9/824 [00:10<16:09,  1.19s/it, training_loss=0.403]
# Epoch 1:   1%|          | 9/824 [00:12<16:09,  1.19s/it, training_loss=0.367]
# Epoch 1:   1%|          | 10/824 [00:12<16:03,  1.18s/it, training_loss=0.367]
# Epoch 1:   1%|          | 10/824 [00:13<16:03,  1.18s/it, training_loss=0.332]
# Epoch 1:   1%|▏         | 11/824 [00:13<16:06,  1.19s/it, training_loss=0.332]
# Epoch 1:   1%|▏         | 11/824 [00:14<16:06,  1.19s/it, training_loss=0.232]
# Epoch 1:   1%|▏         | 12/824 [00:14<16:10,  1.20s/it, training_loss=0.232]
# Epoch 1:   1%|▏         | 12/824 [00:15<16:10,  1.20s/it, training_loss=0.064]
# Epoch 1:   2%|▏         | 13/824 [00:15<15:57,  1.18s/it, training_loss=0.064]
# Epoch 1:   2%|▏         | 13/824 [00:16<15:57,  1.18s/it, training_loss=0.146]
# Epoch 1:   2%|▏         | 14/824 [00:16<15:57,  1.18s/it, training_loss=0.146]
# Epoch 1:   2%|▏         | 14/824 [00:17<15:57,  1.18s/it, training_loss=0.554]
# Epoch 1:   2%|▏         | 15/824 [00:17<15:51,  1.18s/it, training_loss=0.554]
# Epoch 1:   2%|▏         | 15/824 [00:19<15:51,  1.18s/it, training_loss=0.243]
# Epoch 1:   2%|▏         | 16/824 [00:19<15:45,  1.17s/it, training_loss=0.243]
# Epoch 1:   2%|▏         | 16/824 [00:20<15:45,  1.17s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 17/824 [00:20<16:04,  1.20s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 17/824 [00:21<16:04,  1.20s/it, training_loss=0.514]
# Epoch 1:   2%|▏         | 18/824 [00:21<16:25,  1.22s/it, training_loss=0.514]
# Epoch 1:   2%|▏         | 18/824 [00:22<16:25,  1.22s/it, training_loss=0.599]
# Epoch 1:   2%|▏         | 19/824 [00:22<16:21,  1.22s/it, training_loss=0.599]
# Epoch 1:   2%|▏         | 19/824 [00:24<16:21,  1.22s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 20/824 [00:24<16:19,  1.22s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 20/824 [00:25<16:19,  1.22s/it, training_loss=0.343]
# Epoch 1:   3%|▎         | 21/824 [00:25<16:02,  1.20s/it, training_loss=0.343]
# Epoch 1:   3%|▎         | 21/824 [00:26<16:02,  1.20s/it, training_loss=0.585]
# Epoch 1:   3%|▎         | 22/824 [00:26<16:00,  1.20s/it, training_loss=0.585]
# Epoch 1:   3%|▎         | 22/824 [00:27<16:00,  1.20s/it, training_loss=0.263]
# Epoch 1:   3%|▎         | 23/824 [00:27<16:02,  1.20s/it, training_loss=0.263]
# Epoch 1:   3%|▎         | 23/824 [00:28<16:02,  1.20s/it, training_loss=0.036]
# Epoch 1:   3%|▎         | 24/824 [00:28<15:54,  1.19s/it, training_loss=0.036]
# Epoch 1:   3%|▎         | 24/824 [00:29<15:54,  1.19s/it, training_loss=0.219]
# Epoch 1:   3%|▎         | 25/824 [00:29<15:44,  1.18s/it, training_loss=0.219]
# Epoch 1:   3%|▎         | 25/824 [00:31<15:44,  1.18s/it, training_loss=0.640]
# Epoch 1:   3%|▎         | 26/824 [00:31<15:46,  1.19s/it, training_loss=0.640]
# Epoch 1:   3%|▎         | 26/824 [00:32<15:46,  1.19s/it, training_loss=0.357]
# Epoch 1:   3%|▎         | 27/824 [00:32<15:49,  1.19s/it, training_loss=0.357]
# Epoch 1:   3%|▎         | 27/824 [00:33<15:49,  1.19s/it, training_loss=0.060]
# Epoch 1:   3%|▎         | 28/824 [00:33<15:49,  1.19s/it, training_loss=0.060]
# Epoch 1:   3%|▎         | 28/824 [00:34<15:49,  1.19s/it, training_loss=0.625]
# Epoch 1:   4%|▎         | 29/824 [00:34<15:51,  1.20s/it, training_loss=0.625]
# Epoch 1:   4%|▎         | 29/824 [00:35<15:51,  1.20s/it, training_loss=0.038]
# Epoch 1:   4%|▎         | 30/824 [00:35<15:47,  1.19s/it, training_loss=0.038]
# Epoch 1:   4%|▎         | 30/824 [00:37<15:47,  1.19s/it, training_loss=0.354]
# Epoch 1:   4%|▍         | 31/824 [00:37<15:43,  1.19s/it, training_loss=0.354]
# Epoch 1:   4%|▍         | 31/824 [00:38<15:43,  1.19s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 32/824 [00:38<15:43,  1.19s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 32/824 [00:39<15:43,  1.19s/it, training_loss=0.200]
# Epoch 1:   4%|▍         | 33/824 [00:39<15:38,  1.19s/it, training_loss=0.200]
# Epoch 1:   4%|▍         | 33/824 [00:40<15:38,  1.19s/it, training_loss=0.180]
# Epoch 1:   4%|▍         | 34/824 [00:40<15:36,  1.19s/it, training_loss=0.180]
# Epoch 1:   4%|▍         | 34/824 [00:41<15:36,  1.19s/it, training_loss=0.523]
# Epoch 1:   4%|▍         | 35/824 [00:41<15:33,  1.18s/it, training_loss=0.523]
# Epoch 1:   4%|▍         | 35/824 [00:43<15:33,  1.18s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 36/824 [00:43<15:35,  1.19s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 36/824 [00:44<15:35,  1.19s/it, training_loss=0.063]
# Epoch 1:   4%|▍         | 37/824 [00:44<15:42,  1.20s/it, training_loss=0.063]
# Epoch 1:   4%|▍         | 37/824 [00:45<15:42,  1.20s/it, training_loss=0.381]
# Epoch 1:   5%|▍         | 38/824 [00:45<15:31,  1.19s/it, training_loss=0.381]
# Epoch 1:   5%|▍         | 38/824 [00:46<15:31,  1.19s/it, training_loss=0.357]
# Epoch 1:   5%|▍         | 39/824 [00:46<15:32,  1.19s/it, training_loss=0.357]
# Epoch 1:   5%|▍         | 39/824 [00:47<15:32,  1.19s/it, training_loss=0.495]
# Epoch 1:   5%|▍         | 40/824 [00:47<15:38,  1.20s/it, training_loss=0.495]
# Epoch 1:   5%|▍         | 40/824 [00:49<15:38,  1.20s/it, training_loss=0.549]
# Epoch 1:   5%|▍         | 41/824 [00:49<15:43,  1.20s/it, training_loss=0.549]
# Epoch 1:   5%|▍         | 41/824 [00:50<15:43,  1.20s/it, training_loss=0.324]
# Epoch 1:   5%|▌         | 42/824 [00:50<15:42,  1.21s/it, training_loss=0.324]
# Epoch 1:   5%|▌         | 42/824 [00:51<15:42,  1.21s/it, training_loss=0.506]
# Epoch 1:   5%|▌         | 43/824 [00:51<15:36,  1.20s/it, training_loss=0.506]
# Epoch 1:   5%|▌         | 43/824 [00:52<15:36,  1.20s/it, training_loss=0.050]
# Epoch 1:   5%|▌         | 44/824 [00:52<15:34,  1.20s/it, training_loss=0.050]
# Epoch 1:   5%|▌         | 44/824 [00:53<15:34,  1.20s/it, training_loss=0.306]
# Epoch 1:   5%|▌         | 45/824 [00:53<15:38,  1.21s/it, training_loss=0.306]
# Epoch 1:   5%|▌         | 45/824 [00:55<15:38,  1.21s/it, training_loss=0.184]
# Epoch 1:   6%|▌         | 46/824 [00:55<15:32,  1.20s/it, training_loss=0.184]
# Epoch 1:   6%|▌         | 46/824 [00:56<15:32,  1.20s/it, training_loss=0.074]
# Epoch 1:   6%|▌         | 47/824 [00:56<15:23,  1.19s/it, training_loss=0.074]
# Epoch 1:   6%|▌         | 47/824 [00:57<15:23,  1.19s/it, training_loss=0.210]
# Epoch 1:   6%|▌         | 48/824 [00:57<15:13,  1.18s/it, training_loss=0.210]
# Epoch 1:   6%|▌         | 48/824 [00:58<15:13,  1.18s/it, training_loss=0.432]
# Epoch 1:   6%|▌         | 49/824 [00:58<15:03,  1.17s/it, training_loss=0.432]
# Epoch 1:   6%|▌         | 49/824 [00:59<15:03,  1.17s/it, training_loss=0.282]
# Epoch 1:   6%|▌         | 50/824 [00:59<15:04,  1.17s/it, training_loss=0.282]
# Epoch 1:   6%|▌         | 50/824 [01:00<15:04,  1.17s/it, training_loss=0.305]
# Epoch 1:   6%|▌         | 51/824 [01:00<15:07,  1.17s/it, training_loss=0.305]
# Epoch 1:   6%|▌         | 51/824 [01:02<15:07,  1.17s/it, training_loss=0.199]
# Epoch 1:   6%|▋         | 52/824 [01:02<15:17,  1.19s/it, training_loss=0.199]
# Epoch 1:   6%|▋         | 52/824 [01:03<15:17,  1.19s/it, training_loss=0.119]
# Epoch 1:   6%|▋         | 53/824 [01:03<15:08,  1.18s/it, training_loss=0.119]
# Epoch 1:   6%|▋         | 53/824 [01:04<15:08,  1.18s/it, training_loss=0.084]
# Epoch 1:   7%|▋         | 54/824 [01:04<15:07,  1.18s/it, training_loss=0.084]
# Epoch 1:   7%|▋         | 54/824 [01:05<15:07,  1.18s/it, training_loss=0.234]
# Epoch 1:   7%|▋         | 55/824 [01:05<15:10,  1.18s/it, training_loss=0.234]
# Epoch 1:   7%|▋         | 55/824 [01:06<15:10,  1.18s/it, training_loss=0.337]
# Epoch 1:   7%|▋         | 56/824 [01:06<15:08,  1.18s/it, training_loss=0.337]
# Epoch 1:   7%|▋         | 56/824 [01:08<15:08,  1.18s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 57/824 [01:08<15:10,  1.19s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 57/824 [01:09<15:10,  1.19s/it, training_loss=0.213]
# Epoch 1:   7%|▋         | 58/824 [01:09<15:13,  1.19s/it, training_loss=0.213]
# Epoch 1:   7%|▋         | 58/824 [01:10<15:13,  1.19s/it, training_loss=0.145]
# Epoch 1:   7%|▋         | 59/824 [01:10<15:15,  1.20s/it, training_loss=0.145]
# Epoch 1:   7%|▋         | 59/824 [01:11<15:15,  1.20s/it, training_loss=0.269]
# Epoch 1:   7%|▋         | 60/824 [01:11<15:08,  1.19s/it, training_loss=0.269]
# Epoch 1:   7%|▋         | 60/824 [01:12<15:08,  1.19s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 61/824 [01:12<15:00,  1.18s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 61/824 [01:13<15:00,  1.18s/it, training_loss=0.278]
# Epoch 1:   8%|▊         | 62/824 [01:13<15:03,  1.19s/it, training_loss=0.278]
# Epoch 1:   8%|▊         | 62/824 [01:15<15:03,  1.19s/it, training_loss=0.203]
# Epoch 1:   8%|▊         | 63/824 [01:15<15:02,  1.19s/it, training_loss=0.203]
# Epoch 1:   8%|▊         | 63/824 [01:16<15:02,  1.19s/it, training_loss=0.118]
# Epoch 1:   8%|▊         | 64/824 [01:16<15:02,  1.19s/it, training_loss=0.118]
# Epoch 1:   8%|▊         | 64/824 [01:17<15:02,  1.19s/it, training_loss=0.400]
# Epoch 1:   8%|▊         | 65/824 [01:17<14:57,  1.18s/it, training_loss=0.400]
# Epoch 1:   8%|▊         | 65/824 [01:18<14:57,  1.18s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 66/824 [01:18<15:00,  1.19s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 66/824 [01:19<15:00,  1.19s/it, training_loss=0.235]
# Epoch 1:   8%|▊         | 67/824 [01:19<15:00,  1.19s/it, training_loss=0.235]
# Epoch 1:   8%|▊         | 67/824 [01:21<15:00,  1.19s/it, training_loss=0.330]
# Epoch 1:   8%|▊         | 68/824 [01:21<14:50,  1.18s/it, training_loss=0.330]
# Epoch 1:   8%|▊         | 68/824 [01:22<14:50,  1.18s/it, training_loss=0.098]
# Epoch 1:   8%|▊         | 69/824 [01:22<14:54,  1.18s/it, training_loss=0.098]
# Epoch 1:   8%|▊         | 69/824 [01:23<14:54,  1.18s/it, training_loss=0.284]
# Epoch 1:   8%|▊         | 70/824 [01:23<14:53,  1.18s/it, training_loss=0.284]
# Epoch 1:   8%|▊         | 70/824 [01:24<14:53,  1.18s/it, training_loss=0.379]
# Epoch 1:   9%|▊         | 71/824 [01:24<14:57,  1.19s/it, training_loss=0.379]
# Epoch 1:   9%|▊         | 71/824 [01:25<14:57,  1.19s/it, training_loss=0.128]
# Epoch 1:   9%|▊         | 72/824 [01:25<14:52,  1.19s/it, training_loss=0.128]
# Epoch 1:   9%|▊         | 72/824 [01:26<14:52,  1.19s/it, training_loss=0.121]
# Epoch 1:   9%|▉         | 73/824 [01:26<14:50,  1.19s/it, training_loss=0.121]
# Epoch 1:   9%|▉         | 73/824 [01:28<14:50,  1.19s/it, training_loss=0.178]
# Epoch 1:   9%|▉         | 74/824 [01:28<14:51,  1.19s/it, training_loss=0.178]
# Epoch 1:   9%|▉         | 74/824 [01:29<14:51,  1.19s/it, training_loss=0.171]
# Epoch 1:   9%|▉         | 75/824 [01:29<14:50,  1.19s/it, training_loss=0.171]
# Epoch 1:   9%|▉         | 75/824 [01:30<14:50,  1.19s/it, training_loss=0.069]
# Epoch 1:   9%|▉         | 76/824 [01:30<14:46,  1.19s/it, training_loss=0.069]
# Epoch 1:   9%|▉         | 76/824 [01:31<14:46,  1.19s/it, training_loss=0.160]
# Epoch 1:   9%|▉         | 77/824 [01:31<14:47,  1.19s/it, training_loss=0.160]
# Epoch 1:   9%|▉         | 77/824 [01:32<14:47,  1.19s/it, training_loss=0.150]
# Epoch 1:   9%|▉         | 78/824 [01:32<14:41,  1.18s/it, training_loss=0.150]
# Epoch 1:   9%|▉         | 78/824 [01:34<14:41,  1.18s/it, training_loss=0.155]
# Epoch 1:  10%|▉         | 79/824 [01:34<14:43,  1.19s/it, training_loss=0.155]
# Epoch 1:  10%|▉         | 79/824 [01:35<14:43,  1.19s/it, training_loss=0.215]
# Epoch 1:  10%|▉         | 80/824 [01:35<14:35,  1.18s/it, training_loss=0.215]
# Epoch 1:  10%|▉         | 80/824 [01:36<14:35,  1.18s/it, training_loss=0.323]
# Epoch 1:  10%|▉         | 81/824 [01:36<14:30,  1.17s/it, training_loss=0.323]
# Epoch 1:  10%|▉         | 81/824 [01:37<14:30,  1.17s/it, training_loss=0.244]
# Epoch 1:  10%|▉         | 82/824 [01:37<14:36,  1.18s/it, training_loss=0.244]
# Epoch 1:  10%|▉         | 82/824 [01:38<14:36,  1.18s/it, training_loss=0.239]
# Epoch 1:  10%|█         | 83/824 [01:38<14:38,  1.19s/it, training_loss=0.239]
# Epoch 1:  10%|█         | 83/824 [01:40<14:38,  1.19s/it, training_loss=0.336]
# Epoch 1:  10%|█         | 84/824 [01:40<14:37,  1.19s/it, training_loss=0.336]
# Epoch 1:  10%|█         | 84/824 [01:41<14:37,  1.19s/it, training_loss=0.481]
# Epoch 1:  10%|█         | 85/824 [01:41<14:36,  1.19s/it, training_loss=0.481]
# Epoch 1:  10%|█         | 85/824 [01:42<14:36,  1.19s/it, training_loss=0.105]
# Epoch 1:  10%|█         | 86/824 [01:42<14:35,  1.19s/it, training_loss=0.105]
# Epoch 1:  10%|█         | 86/824 [01:43<14:35,  1.19s/it, training_loss=0.250]
# Epoch 1:  11%|█         | 87/824 [01:43<14:32,  1.18s/it, training_loss=0.250]
# Epoch 1:  11%|█         | 87/824 [01:44<14:32,  1.18s/it, training_loss=0.342]
# Epoch 1:  11%|█         | 88/824 [01:44<14:29,  1.18s/it, training_loss=0.342]
# Epoch 1:  11%|█         | 88/824 [01:45<14:29,  1.18s/it, training_loss=0.204]
# Epoch 1:  11%|█         | 89/824 [01:45<14:25,  1.18s/it, training_loss=0.204]
# Epoch 1:  11%|█         | 89/824 [01:47<14:25,  1.18s/it, training_loss=0.159]
# Epoch 1:  11%|█         | 90/824 [01:47<14:23,  1.18s/it, training_loss=0.159]
# Epoch 1:  11%|█         | 90/824 [01:48<14:23,  1.18s/it, training_loss=0.114]
# Epoch 1:  11%|█         | 91/824 [01:48<14:19,  1.17s/it, training_loss=0.114]
# Epoch 1:  11%|█         | 91/824 [01:49<14:19,  1.17s/it, training_loss=0.124]
# Epoch 1:  11%|█         | 92/824 [01:49<14:42,  1.21s/it, training_loss=0.124]
# Epoch 1:  11%|█         | 92/824 [01:50<14:42,  1.21s/it, training_loss=0.086]
# Epoch 1:  11%|█▏        | 93/824 [01:50<14:32,  1.19s/it, training_loss=0.086]
# Epoch 1:  11%|█▏        | 93/824 [01:51<14:32,  1.19s/it, training_loss=0.251]
# Epoch 1:  11%|█▏        | 94/824 [01:51<14:42,  1.21s/it, training_loss=0.251]
# Epoch 1:  11%|█▏        | 94/824 [01:53<14:42,  1.21s/it, training_loss=0.149]
# Epoch 1:  12%|█▏        | 95/824 [01:53<14:37,  1.20s/it, training_loss=0.149]
# Epoch 1:  12%|█▏        | 95/824 [01:54<14:37,  1.20s/it, training_loss=0.184]
# Epoch 1:  12%|█▏        | 96/824 [01:54<14:30,  1.20s/it, training_loss=0.184]
# Epoch 1:  12%|█▏        | 96/824 [01:55<14:30,  1.20s/it, training_loss=0.124]
# Epoch 1:  12%|█▏        | 97/824 [01:55<14:26,  1.19s/it, training_loss=0.124]
# Epoch 1:  12%|█▏        | 97/824 [01:56<14:26,  1.19s/it, training_loss=0.195]
# Epoch 1:  12%|█▏        | 98/824 [01:56<14:41,  1.21s/it, training_loss=0.195]
# Epoch 1:  12%|█▏        | 98/824 [01:57<14:41,  1.21s/it, training_loss=0.142]
# Epoch 1:  12%|█▏        | 99/824 [01:57<14:34,  1.21s/it, training_loss=0.142]
# Epoch 1:  12%|█▏        | 99/824 [01:59<14:34,  1.21s/it, training_loss=0.120]
# Epoch 1:  12%|█▏        | 100/824 [01:59<14:24,  1.19s/it, training_loss=0.120]
# Epoch 1:  12%|█▏        | 100/824 [02:00<14:24,  1.19s/it, training_loss=0.256]
# Epoch 1:  12%|█▏        | 101/824 [02:00<14:17,  1.19s/it, training_loss=0.256]
# Epoch 1:  12%|█▏        | 101/824 [02:01<14:17,  1.19s/it, training_loss=0.223]
# Epoch 1:  12%|█▏        | 102/824 [02:01<14:15,  1.18s/it, training_loss=0.223]
# Epoch 1:  12%|█▏        | 102/824 [02:02<14:15,  1.18s/it, training_loss=0.220]
# Epoch 1:  12%|█▎        | 103/824 [02:02<14:14,  1.19s/it, training_loss=0.220]
# Epoch 1:  12%|█▎        | 103/824 [02:03<14:14,  1.19s/it, training_loss=0.231]
# Epoch 1:  13%|█▎        | 104/824 [02:03<14:15,  1.19s/it, training_loss=0.231]
# Epoch 1:  13%|█▎        | 104/824 [02:05<14:15,  1.19s/it, training_loss=0.205]
# Epoch 1:  13%|█▎        | 105/824 [02:05<14:18,  1.19s/it, training_loss=0.205]
# Epoch 1:  13%|█▎        | 105/824 [02:06<14:18,  1.19s/it, training_loss=0.170]
# Epoch 1:  13%|█▎        | 106/824 [02:06<14:15,  1.19s/it, training_loss=0.170]
# Epoch 1:  13%|█▎        | 106/824 [02:07<14:15,  1.19s/it, training_loss=0.174]
# Epoch 1:  13%|█▎        | 107/824 [02:07<14:11,  1.19s/it, training_loss=0.174]
# Epoch 1:  13%|█▎        | 107/824 [02:08<14:11,  1.19s/it, training_loss=0.186]
# Epoch 1:  13%|█▎        | 108/824 [02:08<14:12,  1.19s/it, training_loss=0.186]
# Epoch 1:  13%|█▎        | 108/824 [02:09<14:12,  1.19s/it, training_loss=0.177]
# Epoch 1:  13%|█▎        | 109/824 [02:09<14:07,  1.19s/it, training_loss=0.177]
# Epoch 1:  13%|█▎        | 109/824 [02:10<14:07,  1.19s/it, training_loss=0.327]
# Epoch 1:  13%|█▎        | 110/824 [02:10<13:59,  1.18s/it, training_loss=0.327]
# Epoch 1:  13%|█▎        | 110/824 [02:12<13:59,  1.18s/it, training_loss=0.230]
# Epoch 1:  13%|█▎        | 111/824 [02:12<14:01,  1.18s/it, training_loss=0.230]
# Epoch 1:  13%|█▎        | 111/824 [02:13<14:01,  1.18s/it, training_loss=0.131]
# Epoch 1:  14%|█▎        | 112/824 [02:13<13:57,  1.18s/it, training_loss=0.131]
# Epoch 1:  14%|█▎        | 112/824 [02:14<13:57,  1.18s/it, training_loss=0.168]
# Epoch 1:  14%|█▎        | 113/824 [02:14<14:02,  1.19s/it, training_loss=0.168]
# Epoch 1:  14%|█▎        | 113/824 [02:15<14:02,  1.19s/it, training_loss=0.432]
# Epoch 1:  14%|█▍        | 114/824 [02:15<14:02,  1.19s/it, training_loss=0.432]
# Epoch 1:  14%|█▍        | 114/824 [02:16<14:02,  1.19s/it, training_loss=0.109]
# Epoch 1:  14%|█▍        | 115/824 [02:16<13:57,  1.18s/it, training_loss=0.109]
# Epoch 1:  14%|█▍        | 115/824 [02:18<13:57,  1.18s/it, training_loss=0.147]
# Epoch 1:  14%|█▍        | 116/824 [02:18<13:52,  1.18s/it, training_loss=0.147]
# Epoch 1:  14%|█▍        | 116/824 [02:19<13:52,  1.18s/it, training_loss=0.148]
# Epoch 1:  14%|█▍        | 117/824 [02:19<13:51,  1.18s/it, training_loss=0.148]
# Epoch 1:  14%|█▍        | 117/824 [02:20<13:51,  1.18s/it, training_loss=0.162]
# Epoch 1:  14%|█▍        | 118/824 [02:20<13:54,  1.18s/it, training_loss=0.162]
# Epoch 1:  16%|█▋        | 135/824 [02:40<13:26,  1.17s/it, training_loss=0.211]
# Epoch 1:  16%|█▋        | 135/824 [02:41<13:26,  1.17s/it, training_loss=0.075]
# Epoch 1:  17%|█▋        | 136/824 [02:41<13:27,  1.17s/it, training_loss=0.075]
# Epoch 1:  17%|█▋        | 136/824 [02:42<13:27,  1.17s/it, training_loss=0.144]
# Epoch 1:  17%|█▋        | 137/824 [02:42<13:31,  1.18s/it, training_loss=0.144]
# Epoch 1:  17%|█▋        | 137/824 [02:44<13:31,  1.18s/it, training_loss=0.076]
# Epoch 1:  17%|█▋        | 138/824 [02:44<13:23,  1.17s/it, training_loss=0.076]
# Epoch 1:  17%|█▋        | 138/824 [02:45<13:23,  1.17s/it, training_loss=0.230]
# Epoch 1:  17%|█▋        | 139/824 [02:45<13:28,  1.18s/it, training_loss=0.230]
# Epoch 1:  17%|█▋        | 139/824 [02:46<13:28,  1.18s/it, training_loss=0.150]
# Epoch 1:  17%|█▋        | 140/824 [02:46<13:24,  1.18s/it, training_loss=0.150]
# Epoch 1:  17%|█▋        | 140/824 [02:47<13:24,  1.18s/it, training_loss=0.467]
# Epoch 1:  17%|█▋        | 141/824 [02:47<13:29,  1.18s/it, training_loss=0.467]
# Epoch 1:  17%|█▋        | 141/824 [02:48<13:29,  1.18s/it, training_loss=0.045]
# Epoch 1:  17%|█▋        | 142/824 [02:48<13:26,  1.18s/it, training_loss=0.045]
# Epoch 1:  17%|█▋        | 142/824 [02:49<13:26,  1.18s/it, training_loss=0.207]
# Epoch 1:  17%|█▋        | 143/824 [02:49<13:24,  1.18s/it, training_loss=0.207]
# Epoch 1:  17%|█▋        | 143/824 [02:51<13:24,  1.18s/it, training_loss=0.162]
# Epoch 1:  17%|█▋        | 144/824 [02:51<13:23,  1.18s/it, training_loss=0.162]
# Epoch 1:  17%|█▋        | 144/824 [02:52<13:23,  1.18s/it, training_loss=0.088]
# Epoch 1:  18%|█▊        | 145/824 [02:52<13:15,  1.17s/it, training_loss=0.088]
# Epoch 1:  18%|█▊        | 145/824 [02:53<13:15,  1.17s/it, training_loss=0.117]
# Epoch 1:  18%|█▊        | 146/824 [02:53<13:25,  1.19s/it, training_loss=0.117]
# Epoch 1:  18%|█▊        | 146/824 [02:54<13:25,  1.19s/it, training_loss=0.076]
# Epoch 1:  18%|█▊        | 147/824 [02:54<13:25,  1.19s/it, training_loss=0.076]
# Epoch 1:  18%|█▊        | 147/824 [02:55<13:25,  1.19s/it, training_loss=0.071]
# Epoch 1:  18%|█▊        | 148/824 [02:55<13:26,  1.19s/it, training_loss=0.071]
# Epoch 1:  18%|█▊        | 148/824 [02:57<13:26,  1.19s/it, training_loss=0.138]
# Epoch 1:  18%|█▊        | 149/824 [02:57<13:20,  1.19s/it, training_loss=0.138]
# Epoch 1:  18%|█▊        | 149/824 [02:58<13:20,  1.19s/it, training_loss=0.063]
# Epoch 1:  18%|█▊        | 150/824 [02:58<13:18,  1.18s/it, training_loss=0.063]
# Epoch 1:  18%|█▊        | 150/824 [02:59<13:18,  1.18s/it, training_loss=0.085]
# Epoch 1:  18%|█▊        | 151/824 [02:59<13:03,  1.16s/it, training_loss=0.085]
# Epoch 1:  18%|█▊        | 151/824 [03:00<13:03,  1.16s/it, training_loss=0.359]
# Epoch 1:  18%|█▊        | 152/824 [03:00<13:05,  1.17s/it, training_loss=0.359]
# Epoch 1:  18%|█▊        | 152/824 [03:01<13:05,  1.17s/it, training_loss=0.099]
# Epoch 1:  19%|█▊        | 153/824 [03:01<12:59,  1.16s/it, training_loss=0.099]
# Epoch 1:  19%|█▊        | 153/824 [03:02<12:59,  1.16s/it, training_loss=0.039]
# Epoch 1:  19%|█▊        | 154/824 [03:02<13:04,  1.17s/it, training_loss=0.039]
# Epoch 1:  19%|█▊        | 154/824 [03:04<13:04,  1.17s/it, training_loss=0.171]
# Epoch 1:  19%|█▉        | 155/824 [03:04<13:06,  1.18s/it, training_loss=0.171]
# Epoch 1:  19%|█▉        | 155/824 [03:05<13:06,  1.18s/it, training_loss=0.100]
# Epoch 1:  19%|█▉        | 156/824 [03:05<13:08,  1.18s/it, training_loss=0.100]
# Epoch 1:  19%|█▉        | 156/824 [03:06<13:08,  1.18s/it, training_loss=0.359]
# Epoch 1:  19%|█▉        | 157/824 [03:06<13:14,  1.19s/it, training_loss=0.359]
# Epoch 1:  19%|█▉        | 157/824 [03:07<13:14,  1.19s/it, training_loss=0.176]
# Epoch 1:  19%|█▉        | 158/824 [03:07<13:09,  1.19s/it, training_loss=0.176]
# Epoch 1:  19%|█▉        | 158/824 [03:08<13:09,  1.19s/it, training_loss=0.167]
# Epoch 1:  19%|█▉        | 159/824 [03:08<13:05,  1.18s/it, training_loss=0.167]
# Epoch 1:  19%|█▉        | 159/824 [03:09<13:05,  1.18s/it, training_loss=0.135]
# Epoch 1:  19%|█▉        | 160/824 [03:09<12:56,  1.17s/it, training_loss=0.135]
# Epoch 1:  19%|█▉        | 160/824 [03:11<12:56,  1.17s/it, training_loss=0.241]
# Epoch 1:  20%|█▉        | 161/824 [03:11<12:57,  1.17s/it, training_loss=0.241]
# Epoch 1:  20%|█▉        | 161/824 [03:12<12:57,  1.17s/it, training_loss=0.039]
# Epoch 1:  20%|█▉        | 162/824 [03:12<13:04,  1.19s/it, training_loss=0.039]
# Epoch 1:  20%|█▉        | 162/824 [03:13<13:04,  1.19s/it, training_loss=0.230]
# Epoch 1:  20%|█▉        | 163/824 [03:13<13:02,  1.18s/it, training_loss=0.230]
# Epoch 1:  20%|█▉        | 163/824 [03:14<13:02,  1.18s/it, training_loss=0.078]
# Epoch 1:  20%|█▉        | 164/824 [03:14<12:59,  1.18s/it, training_loss=0.078]
# Epoch 1:  20%|█▉        | 164/824 [03:15<12:59,  1.18s/it, training_loss=0.085]
# Epoch 1:  20%|██        | 165/824 [03:15<12:58,  1.18s/it, training_loss=0.085]
# Epoch 1:  20%|██        | 165/824 [03:17<12:58,  1.18s/it, training_loss=0.158]
# Epoch 1:  20%|██        | 166/824 [03:17<13:11,  1.20s/it, training_loss=0.158]
# Epoch 1:  24%|██▍       | 198/824 [03:56<12:15,  1.17s/it, training_loss=0.034]
# Epoch 1:  24%|██▍       | 199/824 [03:56<12:09,  1.17s/it, training_loss=0.034]
# Epoch 1:  24%|██▍       | 199/824 [03:57<12:09,  1.17s/it, training_loss=0.117]
# Epoch 1:  24%|██▍       | 200/824 [03:57<12:14,  1.18s/it, training_loss=0.117]
# Epoch 1:  24%|██▍       | 200/824 [03:58<12:14,  1.18s/it, training_loss=0.208]
# Epoch 1:  24%|██▍       | 201/824 [03:58<12:15,  1.18s/it, training_loss=0.208]
# Epoch 1:  24%|██▍       | 201/824 [03:59<12:15,  1.18s/it, training_loss=0.027]
# Epoch 1:  25%|██▍       | 202/824 [03:59<12:10,  1.17s/it, training_loss=0.027]
# Epoch 1:  25%|██▍       | 202/824 [04:00<12:10,  1.17s/it, training_loss=0.053]
# Epoch 1:  25%|██▍       | 203/824 [04:00<12:11,  1.18s/it, training_loss=0.053]
# Epoch 1:  25%|██▍       | 203/824 [04:02<12:11,  1.18s/it, training_loss=0.167]
# Epoch 1:  25%|██▍       | 204/824 [04:02<12:08,  1.17s/it, training_loss=0.167]
# Epoch 1:  25%|██▍       | 204/824 [04:03<12:08,  1.17s/it, training_loss=0.086]
# Epoch 1:  25%|██▍       | 205/824 [04:03<12:08,  1.18s/it, training_loss=0.086]
# Epoch 1:  25%|██▍       | 205/824 [04:04<12:08,  1.18s/it, training_loss=0.219]
# Epoch 1:  25%|██▌       | 206/824 [04:04<12:03,  1.17s/it, training_loss=0.219]
# Epoch 1:  25%|██▌       | 206/824 [04:05<12:03,  1.17s/it, training_loss=0.202]
# Epoch 1:  25%|██▌       | 207/824 [04:05<12:00,  1.17s/it, training_loss=0.202]
# Epoch 1:  25%|██▌       | 207/824 [04:06<12:00,  1.17s/it, training_loss=0.085]
# Epoch 1:  25%|██▌       | 208/824 [04:06<12:02,  1.17s/it, training_loss=0.085]
# Epoch 1:  25%|██▌       | 208/824 [04:07<12:02,  1.17s/it, training_loss=0.069]
# Epoch 1:  25%|██▌       | 209/824 [04:07<11:52,  1.16s/it, training_loss=0.069]
# Epoch 1:  25%|██▌       | 209/824 [04:08<11:52,  1.16s/it, training_loss=0.021]
# Epoch 1:  25%|██▌       | 210/824 [04:08<11:54,  1.16s/it, training_loss=0.021]
# Epoch 1:  25%|██▌       | 210/824 [04:10<11:54,  1.16s/it, training_loss=0.100]
# Epoch 1:  26%|██▌       | 211/824 [04:10<11:53,  1.16s/it, training_loss=0.100]
# Epoch 1:  26%|██▌       | 211/824 [04:11<11:53,  1.16s/it, training_loss=0.279]
# Epoch 1:  26%|██▌       | 212/824 [04:11<12:00,  1.18s/it, training_loss=0.279]
# Epoch 1:  26%|██▌       | 212/824 [04:12<12:00,  1.18s/it, training_loss=0.315]
# Epoch 1:  26%|██▌       |
# Epoch 1:  30%|██▉       | 247/824 [04:53<11:30,  1.20s/it, training_loss=0.033]
# Epoch 1:  30%|███       | 248/824 [04:53<11:26,  1.19s/it, training_loss=0.033]
# Epoch 1:  30%|███       | 248/824 [04:55<11:26,  1.19s/it, training_loss=0.152]
# Epoch 1:  30%|███       | 249/824 [04:55<11:21,  1.19s/it, training_loss=0.152]
# Epoch 1:  30%|███       | 249/824 [04:56<11:21,  1.19s/it, training_loss=0.088]
# Epoch 1:  30%|███       | 250/824 [04:56<11:24,  1.19s/it, training_loss=0.088]
# Epoch 1:  30%|███       | 250/824 [04:57<11:24,  1.19s/it, training_loss=0.100]
# Epoch 1:  30%|███       | 251/824 [04:57<11:24,  1.19s/it, training_loss=0.100]
# Epoch 1:  30%|███       | 251/824 [04:58<11:24,  1.19s/it, training_loss=0.232]
# Epoch 1:  31%|███       | 252/824 [04:58<11:14,  1.18s/it, training_loss=0.232]
# Epoch 1:  31%|███       | 252/824 [04:59<11:14,  1.18s/it, training_loss=0.225]
# Epoch 1:  31%|███       | 253/824 [04:59<11:04,  1.16s/it, training_loss=0.225]
# Epoch 1:  31%|███       | 253/824 [05:00<11:04,  1.16s/it, training_loss=0.293]
# Epoch 1:  31%|███       | 254/824 [05:00<11:02,  1.16s/it, training_loss=0.293]
# Epoch 1:  31%|███       | 254/824 [05:02<11:02,  1.16s/it, training_loss=0.037]
# Epoch 1:  31%|███       | 255/824 [05:02<11:08,  1.18s/it, training_loss=0.037]
# Epoch 1:  31%|███       | 255/824 [05:03<11:08,  1.18s/it, training_loss=0.087]
# Epoch 1:  31%|███       | 256/824 [05:03<11:05,  1.17s/it, training_loss=0.087]
# Epoch 1:  31%|███       | 256/824 [05:04<11:05,  1.17s/it, training_loss=0.034]
# Epoch 1:  31%|███       | 257/824 [05:04<11:06,  1.18s/it, training_loss=0.034]
# Epoch 1:  31%|███       | 257/824 [05:05<11:06,  1.18s/it, training_loss=0.056]
# Epoch 1:  31%|███▏      | 258/824 [05:05<11:05,  1.18s/it, training_loss=0.056]
# Epoch 1:  31%|███▏      | 258/824 [05:06<11:05,  1.18s/it, training_loss=0.237]
# Epoch 1:  31%|███▏      | 259/824 [05:06<11:01,  1.17s/it, training_loss=0.237]
# Epoch 1:  31%|███▏      | 259/824 [05:07<11:01,  1.17s/it, training_loss=0.106]
# Epoch 1:  32%|███▏      | 260/824 [05:07<11:01,  1.17s/it, training_loss=0.106]
# Epoch 1:  32%|███▏      | 260/824 [05:09<11:01,  1.17s/it, training_loss=0.406]
# Epoch 1:  32%|███▏      | 261/824 [05:09<10:52,  1.16s/it, training_loss=0.406]
# Epoch 1:  32%|███▏      | 261/824 [05:10<10:52,  1.16s/it, training_loss=0.021]
# Epoch 1:  32%|███▏      | 262/824 [05:10<10:53,  1.16s/it, training_loss=0.021]
# Epoch 1:  32%|███▏      | 262/824 [05:11<10:53,  1.16s/it, training_loss=0.258]
# Epoch 1:  32%|███▏      | 263/824 [05:11<10:50,  1.16s/it, training_loss=0.258]
# Epoch 1:  32%|███▏      | 263/824 [05:12<10:50,  1.16s/it, training_loss=0.261]
# Epoch 1:  32%|███▏      | 264/824 [05:12<10:51,  1.16s/it, training_loss=0.261]
# Epoch 1:  32%|███▏      | 264/824 [05:13<10:51,  1.16s/it, training_loss=0.081]
# Epoch 1:  32%|███▏      | 265/824 [05:13<10:50,  1.16s/it, training_loss=0.081]
# Epoch 1:  32%|███▏      | 265/824 [05:14<10:50,  1.16s/it, training_loss=0.080]
# Epoch 1:  32%|███▏      | 266/824 [05:14<10:50,  1.17s/it, training_loss=0.080]
# Epoch 1:  32%|███▏      | 266/824 [05:16<10:50,  1.17s/it, training_loss=0.203]
# Epoch 1:  32%|███▏      | 267/824 [05:16<10:49,  1.17s/it, training_loss=0.203]
# Epoch 1:  32%|███▏      | 267/824 [05:17<10:49,  1.17s/it, training_loss=0.092]
# Epoch 1:  33%|███▎      | 268/824 [05:17<10:50,  1.17s/it, training_loss=0.092]
# Epoch 1:  33%|███▎      | 268/824 [05:18<10:50,  1.17s/it, training_loss=0.190]
# Epoch 1:  33%|███▎      | 269/824 [05:18<10:47,  1.17s/it, training_loss=0.190]
# Epoch 1:  33%|███▎      | 269/824 [05:19<10:47,  1.17s/it, training_loss=0.106]
# Epoch 1:  33%|███▎      | 270/824 [05:19<10:57,  1.19s/it, training_loss=0.106]
# Epoch 1:  33%|███▎      | 270/824 [05:20<10:57,  1.19s/it, training_loss=0.272]
# Epoch 1:  33%|███▎      | 271/824 [05:20<10:50,  1.18s/it, training_loss=0.272]
# Epoch 1:  33%|███▎      | 271/824 [05:21<10:50,  1.18s/it, training_loss=0.238]
# Epoch 1:  33%|███▎      | 272/824 [05:21<10:48,  1.17s/it, training_loss=0.238]
# Epoch 1:  33%|███▎      | 272/824 [05:23<10:48,  1.17s/it, training_loss=0.219]
# Epoch 1:  33%|███▎      | 273/824 [05:23<10:42,  1.17s/it, training_loss=0.219]
# Epoch 1:  33%|███▎      | 273/824 [05:24<10:42,  1.17s/it, training_loss=0.171]
# Epoch 1:  33%|███▎      | 274/824 [05:24<10:43,  1.17s/it, training_loss=0.171]
# Epoch 1:  33%|███▎      | 274/824 [05:25<10:43,  1.17s/it, training_loss=0.031]
# Epoch 1:  33%|███▎      | 275/824 [05:25<10:40,  1.17s/it, training_loss=0.031]
# Epoch 1:  33%|███▎      | 275/824 [05:26<10:40,  1.17s/it, training_loss=0.050]
# Epoch 1:  33%|███▎      | 276/824 [05:26<10:40,  1.17s/it, training_loss=0.050]
# Epoch 1:  33%|███▎      | 276/824 [05:27<10:40,  1.17s/it, training_loss=0.024]
# Epoch 1:  34%|███▎      | 277/824 [05:27<10:36,  1.16s/it, training_loss=0.024]
# Epoch 1:  34%|███▎      | 277/824 [05:28<10:36,  1.16s/it, training_loss=0.664]
# Epoch 1:  34%|███▎      | 278/824 [05:28<10:40,  1.17s/it, training_loss=0.664]
# Epoch 1:  34%|███▎      | 278/824 [05:30<10:40,  1.17s/it, training_loss=0.164]
# Epoch 1:  34%|███▍      | 279/824 [05:30<10:37,  1.17s/it, training_loss=0.164]
# Epoch 1:  36%|███▌      | 295/824 [05:48<10:20,  1.17s/it, training_loss=0.040]
# Epoch 1:  36%|███▌      | 295/824 [05:50<10:20,  1.17s/it, training_loss=0.161]
# Epoch 1:  36%|███▌      | 296/824 [05:50<10:30,  1.19s/it, training_loss=0.161]
# Epoch 1:  36%|███▌      | 296/824 [05:51<10:30,  1.19s/it, training_loss=0.030]
# Epoch 1:  36%|███▌      | 297/824 [05:51<10:27,  1.19s/it, training_loss=0.030]
# Epoch 1:  36%|███▌      | 297/824 [05:52<10:27,  1.19s/it, training_loss=0.260]
# Epoch 1:  36%|███▌      | 298/824 [05:52<10:23,  1.18s/it, training_loss=0.260]
# Epoch 1:  36%|███▌      | 298/824 [05:53<10:23,  1.18s/it, training_loss=0.303]
# Epoch 1:  36%|███▋      | 299/824 [05:53<10:19,  1.18s/it, training_loss=0.303]
# Epoch 1:  36%|███▋      | 299/824 [05:54<10:19,  1.18s/it, training_loss=0.076]
# Epoch 1:  36%|███▋      | 300/824 [05:54<10:16,  1.18s/it, training_loss=0.076]
# Epoch 1:  36%|███▋      | 300/824 [05:55<10:16,  1.18s/it, training_loss=0.032]
# ...
# Epoch 3:  88%|████████▊ | 726/824 [13:35<01:42,  1.04s/it, training_loss=0.221]
# Epoch 3:  88%|████████▊ | 727/824 [13:35<01:41,  1.04s/it, training_loss=0.221]
# Epoch 3:  88%|████████▊ | 727/824 [13:36<01:41,  1.04s/it, training_loss=0.065]
# Epoch 3:  88%|████████▊ | 728/824 [13:36<01:39,  1.04s/it, training_loss=0.065]
# Epoch 3:  88%|████████▊ | 728/824 [13:37<01:39,  1.04s/it, training_loss=0.001]
# Epoch 3:  88%|████████▊ | 729/824 [13:37<01:38,  1.04s/it, training_loss=0.001]
# Epoch 3:  88%|████████▊ | 729/824 [13:38<01:38,  1.04s/it, training_loss=0.003]
# Epoch 3:  89%|████████▊ | 730/824 [13:38<01:37,  1.04s/it, training_loss=0.003]
# Epoch 3:  89%|████████▊ | 730/824 [13:39<01:37,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▊ | 731/824 [13:39<01:36,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▊ | 731/824 [13:40<01:36,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 732/824 [13:40<01:35,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 732/824 [13:41<01:35,  1.04s/it, training_loss=0.113]
# Epoch 3:  89%|████████▉ | 733/824 [13:41<01:34,  1.04s/it, training_loss=0.113]
# Epoch 3:  89%|████████▉ | 733/824 [13:42<01:34,  1.04s/it, training_loss=0.000]
# Epoch 3:  89%|████████▉ | 734/824 [13:42<01:33,  1.03s/it, training_loss=0.000]
# Epoch 3:  89%|████████▉ | 734/824 [13:43<01:33,  1.03s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 735/824 [13:43<01:32,  1.03s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 735/824 [13:44<01:32,  1.03s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 736/824 [13:44<01:31,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 736/824 [13:45<01:31,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 737/824 [13:45<01:30,  1.04s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 737/824 [13:46<01:30,  1.04s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 738/824 [13:46<01:29,  1.04s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 738/824 [13:47<01:29,  1.04s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 739/824 [13:47<01:28,  1.04s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 739/824 [13:48<01:28,  1.04s/it, training_loss=0.004]
# Epoch 3:  90%|████████▉ | 740/824 [13:48<01:27,  1.04s/it, training_loss=0.004]
# Epoch 3:  90%|████████▉ | 740/824 [13:49<01:27,  1.04s/it, training_loss=0.000]
# Epoch 3:  90%|████████▉ | 741/824 [13:49<01:26,  1.04s/it, training_loss=0.000]
# Epoch 3:  90%|████████▉ | 741/824 [13:50<01:26,  1.04s/it, training_loss=0.000]
# Epoch 3:  90%|█████████ | 742/824 [13:50<01:25,  1.04s/it, training_loss=0.000]
# Epoch 3:  90%|█████████ | 742/824 [13:51<01:25,  1.04s/it, training_loss=0.153]
# Epoch 3:  90%|█████████ | 743/824 [13:51<01:23,  1.03s/it, training_loss=0.153]
# Epoch 3:  90%|█████████ | 743/824 [13:52<01:23,  1.03s/it, training_loss=0.464]
# Epoch 3:  90%|█████████ | 744/824 [13:52<01:22,  1.03s/it, training_loss=0.464]
# Epoch 3:  90%|█████████ | 744/824 [13:53<01:22,  1.03s/it, training_loss=0.027]
# Epoch 3:  90%|█████████ | 745/824 [13:53<01:21,  1.04s/it, training_loss=0.027]
# Epoch 3:  90%|█████████ | 745/824 [13:54<01:21,  1.04s/it, training_loss=0.006]
# Epoch 3:  91%|█████████ | 746/824 [13:54<01:19,  1.02s/it, training_loss=0.006]
# Epoch 3:  91%|█████████ | 746/824 [13:55<01:19,  1.02s/it, training_loss=0.413]
# Epoch 3:  91%|█████████ | 747/824 [13:55<01:19,  1.03s/it, training_loss=0.413]
# Epoch 3:  91%|█████████ | 747/824 [13:56<01:19,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 748/824 [13:56<01:18,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 748/824 [13:58<01:18,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 749/824 [13:58<01:17,  1.04s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 749/824 [13:59<01:17,  1.04s/it, training_loss=0.189]
# Epoch 3:  91%|█████████ | 750/824 [13:59<01:17,  1.04s/it, training_loss=0.189]
# Epoch 3:  91%|█████████ | 750/824 [14:00<01:17,  1.04s/it, training_loss=0.402]
# Epoch 3:  91%|█████████ | 751/824 [14:00<01:15,  1.03s/it, training_loss=0.402]
# Epoch 3:  91%|█████████ | 751/824 [14:01<01:15,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 752/824 [14:01<01:13,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 752/824 [14:02<01:13,  1.03s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 753/824 [14:02<01:12,  1.02s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 753/824 [14:03<01:12,  1.02s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 754/824 [14:03<01:12,  1.03s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 754/824 [14:04<01:12,  1.03s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 755/824 [14:04<01:11,  1.04s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 755/824 [14:05<01:11,  1.04s/it, training_loss=0.338]
# Epoch 3:  92%|█████████▏| 756/824 [14:05<01:11,  1.05s/it, training_loss=0.338]
# Epoch 3:  92%|█████████▏| 756/824 [14:06<01:11,  1.05s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 757/824 [14:06<01:10,  1.05s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 757/824 [14:07<01:10,  1.05s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 758/824 [14:07<01:08,  1.03s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 758/824 [14:08<01:08,  1.03s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 759/824 [14:08<01:07,  1.04s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 759/824 [14:09<01:07,  1.04s/it, training_loss=0.400]
# Epoch 3:  92%|█████████▏| 760/824 [14:09<01:05,  1.03s/it, training_loss=0.400]
# Epoch 3:  92%|█████████▏| 760/824 [14:10<01:05,  1.03s/it, training_loss=0.405]
# Epoch 3:  92%|█████████▏| 761/824 [14:10<01:05,  1.03s/it, training_loss=0.405]
# Epoch 3:  92%|█████████▏| 761/824 [14:11<01:05,  1.03s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 762/824 [14:11<01:04,  1.03s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 762/824 [14:12<01:04,  1.03s/it, training_loss=0.011]
# Epoch 3:  93%|█████████▎| 763/824 [14:12<01:03,  1.04s/it, training_loss=0.011]
# Epoch 3:  93%|█████████▎| 763/824 [14:13<01:03,  1.04s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 764/824 [14:13<01:01,  1.03s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 764/824 [14:14<01:01,  1.03s/it, training_loss=0.010]
# Epoch 3:  93%|█████████▎| 765/824 [14:14<01:00,  1.02s/it, training_loss=0.010]
# Epoch 3:  93%|█████████▎| 765/824 [14:15<01:00,  1.02s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 766/824 [14:15<00:58,  1.01s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 766/824 [14:16<00:58,  1.01s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 767/824 [14:16<00:57,  1.01s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 767/824 [14:17<00:57,  1.01s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 768/824 [14:17<00:56,  1.02s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 768/824 [14:18<00:56,  1.02s/it, training_loss=0.007]
# Epoch 3:  93%|█████████▎| 769/824 [14:18<00:55,  1.01s/it, training_loss=0.007]
# Epoch 3:  93%|█████████▎| 769/824 [14:19<00:55,  1.01s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 770/824 [14:19<00:54,  1.02s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 770/824 [14:20<00:54,  1.02s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 771/824 [14:20<00:54,  1.02s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 771/824 [14:21<00:54,  1.02s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 772/824 [14:21<00:53,  1.02s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 772/824 [14:22<00:53,  1.02s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 773/824 [14:22<00:51,  1.01s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 773/824 [14:23<00:51,  1.01s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 774/824 [14:23<00:51,  1.03s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 774/824 [14:24<00:51,  1.03s/it, training_loss=0.004]
# Epoch 3:  94%|█████████▍| 775/824 [14:24<00:50,  1.04s/it, training_loss=0.004]
# Epoch 3:  94%|█████████▍| 775/824 [14:25<00:50,  1.04s/it, training_loss=0.128]
# Epoch 3:  94%|█████████▍| 776/824 [14:25<00:50,  1.04s/it, training_loss=0.128]
# Epoch 3:  94%|█████████▍| 776/824 [14:26<00:50,  1.04s/it, training_loss=0.270]
# Epoch 3:  94%|█████████▍| 777/824 [14:26<00:49,  1.05s/it, training_loss=0.270]
# Epoch 3:  94%|█████████▍| 777/824 [14:27<00:49,  1.05s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 778/824 [14:27<00:48,  1.06s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 778/824 [14:29<00:48,  1.06s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▍| 779/824 [14:29<00:47,  1.06s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▍| 779/824 [14:30<00:47,  1.06s/it, training_loss=0.002]
# Epoch 3:  95%|█████████▍| 780/824 [14:30<00:46,  1.05s/it, training_loss=0.002]
# Epoch 3:  95%|█████████▍| 780/824 [14:31<00:46,  1.05s/it, training_loss=0.396]
# Epoch 3:  95%|█████████▍| 781/824 [14:31<00:44,  1.04s/it, training_loss=0.396]
# Epoch 3:  95%|█████████▍| 781/824 [14:32<00:44,  1.04s/it, training_loss=0.006]
# Epoch 3:  95%|█████████▍| 782/824 [14:32<00:43,  1.04s/it, training_loss=0.006]
# Epoch 3:  95%|█████████▍| 782/824 [14:33<00:43,  1.04s/it, training_loss=0.003]
# Epoch 3:  95%|█████████▌| 783/824 [14:33<00:42,  1.04s/it, training_loss=0.003]
# Epoch 3:  95%|█████████▌| 783/824 [14:34<00:42,  1.04s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 784/824 [14:34<00:41,  1.03s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 784/824 [14:35<00:41,  1.03s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 785/824 [14:35<00:40,  1.03s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 785/824 [14:36<00:40,  1.03s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 786/824 [14:36<00:39,  1.04s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 786/824 [14:37<00:39,  1.04s/it, training_loss=0.011]
# Epoch 3:  96%|█████████▌| 787/824 [14:37<00:38,  1.05s/it, training_loss=0.011]
# Epoch 3:  96%|█████████▌| 787/824 [14:38<00:38,  1.05s/it, training_loss=0.039]
# Epoch 3:  96%|█████████▌| 788/824 [14:38<00:37,  1.05s/it, training_loss=0.039]
# Epoch 3:  96%|█████████▌| 788/824 [14:39<00:37,  1.05s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 789/824 [14:39<00:36,  1.03s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 789/824 [14:40<00:36,  1.03s/it, training_loss=0.004]
# Epoch 3:  96%|█████████▌| 790/824 [14:40<00:35,  1.04s/it, training_loss=0.004]
# Epoch 3:  96%|█████████▌| 790/824 [14:41<00:35,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 791/824 [14:41<00:33,  1.03s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 791/824 [14:42<00:33,  1.03s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 792/824 [14:42<00:33,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 792/824 [14:43<00:33,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 793/824 [14:43<00:32,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 793/824 [14:44<00:32,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 794/824 [14:44<00:31,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 794/824 [14:45<00:31,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 795/824 [14:45<00:30,  1.04s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 795/824 [14:46<00:30,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 796/824 [14:46<00:29,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 796/824 [14:47<00:29,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 797/824 [14:47<00:28,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 797/824 [14:48<00:28,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 798/824 [14:48<00:27,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 798/824 [14:49<00:27,  1.04s/it, training_loss=0.267]
# Epoch 3:  97%|█████████▋| 799/824 [14:49<00:25,  1.04s/it, training_loss=0.267]
# Epoch 3:  97%|█████████▋| 799/824 [14:50<00:25,  1.04s/it, training_loss=0.400]
# Epoch 3:  97%|█████████▋| 800/824 [14:50<00:24,  1.03s/it, training_loss=0.400]
# Epoch 3:  97%|█████████▋| 800/824 [14:51<00:24,  1.03s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 801/824 [14:51<00:23,  1.03s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 801/824 [14:52<00:23,  1.03s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 802/824 [14:52<00:22,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 802/824 [14:53<00:22,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 803/824 [14:53<00:21,  1.04s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 803/824 [14:54<00:21,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 804/824 [14:54<00:20,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 804/824 [14:55<00:20,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 805/824 [14:55<00:19,  1.03s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 805/824 [14:56<00:19,  1.03s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 806/824 [14:56<00:18,  1.03s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 806/824 [14:58<00:18,  1.03s/it, training_loss=0.007]
# Epoch 3:  98%|█████████▊| 807/824 [14:58<00:17,  1.04s/it, training_loss=0.007]
# Epoch 3:  98%|█████████▊| 807/824 [14:59<00:17,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 808/824 [14:59<00:16,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 808/824 [15:00<00:16,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 809/824 [15:00<00:15,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 809/824 [15:01<00:15,  1.04s/it, training_loss=0.006]
# Epoch 3:  98%|█████████▊| 810/824 [15:01<00:14,  1.04s/it, training_loss=0.006]
# Epoch 3:  98%|█████████▊| 810/824 [15:02<00:14,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 811/824 [15:02<00:13,  1.04s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 811/824 [15:03<00:13,  1.04s/it, training_loss=0.003]
# Epoch 3:  99%|█████████▊| 812/824 [15:03<00:12,  1.04s/it, training_loss=0.003]
# Epoch 3:  99%|█████████▊| 812/824 [15:04<00:12,  1.04s/it, training_loss=0.400]
# Epoch 3:  99%|█████████▊| 813/824 [15:04<00:11,  1.04s/it, training_loss=0.400]
# Epoch 3:  99%|█████████▊| 813/824 [15:05<00:11,  1.04s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 814/824 [15:05<00:10,  1.03s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 814/824 [15:06<00:10,  1.03s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 815/824 [15:06<00:09,  1.05s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 815/824 [15:07<00:09,  1.05s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 816/824 [15:07<00:08,  1.05s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 816/824 [15:08<00:08,  1.05s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 817/824 [15:08<00:07,  1.04s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 817/824 [15:09<00:07,  1.04s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 818/824 [15:09<00:06,  1.04s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 818/824 [15:10<00:06,  1.04s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 819/824 [15:10<00:05,  1.04s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 819/824 [15:11<00:05,  1.04s/it, training_loss=0.006]
# Epoch 3: 100%|█████████▉| 820/824 [15:11<00:04,  1.04s/it, training_loss=0.006]
# Epoch 3: 100%|█████████▉| 820/824 [15:12<00:04,  1.04s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 821/824 [15:12<00:03,  1.04s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 821/824 [15:13<00:03,  1.04s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 822/824 [15:13<00:02,  1.04s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 822/824 [15:14<00:02,  1.04s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 823/824 [15:14<00:01,  1.02s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 823/824 [15:15<00:01,  1.02s/it, training_loss=0.001]
# Epoch 3: 100%|██████████| 824/824 [15:15<00:00,  1.01it/s, training_loss=0.001]
#  67%|██████▋   | 2/3 [49:43<17:16, 1036.53s/it]
# Epoch 3
# Training loss: 0.15098944223286398
# 100%|██████████| 3/3 [50:29<00:00, 1009.83s/it]
# Validation loss: 0.538357858375442
# F1 Score (Weighted): 0.871166775606992
# CPU times: user 16h 23min 12s, sys: 20min 33s, total: 16h 43min 45s
# Wall time: 50min 29s

# %% [markdown]
# **Model Evaluation**

# %%
# Load the best model & Make Predictions
# %%time
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('finetuned_finBERT_epoch_1.model', 
                                 map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)

accuracy_per_class(predictions, true_vals)
# Out:
# Class: neutral
# Accuracy: 395/432
#
# Class: negative
# Accuracy: 73/91
#
# Class: positive
# Accuracy: 160/204
#
# CPU times: user 11min 45s, sys: 9.31 s, total: 11min 55s
# Wall time: 37.3 s
