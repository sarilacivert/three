# %% [markdown]
# **Financial News Text Classification Using FinBERT With Pytorch**

# %%
#!pip install transformers

# %%
import warnings
warnings.filterwarnings('ignore') # to avoid warnings

import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

"""
Sklearn Libraries
"""
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

"""
Transformer Libraries
"""
from transformers import BertTokenizer,  AutoModelForSequenceClassification, AdamW, get_linear_schedule_with_warmup
"""
Pytorch Libraries
"""
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset

# %%
def show_headline_distribution(sequence_lengths, figsize = (15,8)):
    
    # Get the percentage of reviews with length > 512
    len_512_plus = [rev_len for rev_len in sequence_lengths if rev_len > 512]
    percent = (len(len_512_plus)/len(sequence_lengths))*100
    
    print("Maximum Sequence Length is {}".format(max(sequence_lengths)))
    
    # Configure the plot size
    plt.figure(figsize = figsize)

    sns.set(style='darkgrid')
    
    # Increase information on the figure
    sns.set(font_scale=1.3)
    
    # Plot the result
    sns.distplot(sequence_lengths, kde = False, rug = False)
    plt.title('Headlines Lengths Distribution')
    plt.xlabel('Headlines Length')
    plt.ylabel('Number of Headlines')

# %%
financial_data = pd.read_csv("/content/sample_data/news2.csv", 
                             encoding = 'ISO-8859-1', 
                             names=['sentiment', 'headline'])

# %%
financial_data.head()
# Out:
#   sentiment                                           headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
financial_data.shape
# Out:
# (4846, 2)

# %%
financial_data.sentiment.value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: sentiment, dtype: int64

# %%
def show_random_headlines(total_number, df):
    
    # Get the random number of reviews
    n_reviews = df.sample(total_number)
    
    # Print each one of the reviews
    for val in list(n_reviews.index):
        print("Reviews #°{}".format(val))
        print(" - Sentiment: {}".format(df.iloc[val]["sentiment"]))
        print(" - News Headline: {}".format(df.iloc[val]["headline"]))
        print("")

# %%
# Show 3 random headlines
show_random_headlines(5, financial_data)
# Out:
# Reviews #°2704
#  - Sentiment: neutral
#  - News Headline: We offer our customers solutions based on renewable raw materials .
#
# Reviews #°1963
#  - Sentiment: neutral
#  - News Headline: The agreement must be approved by the Russian competition authorities before it enters into force .
#
# Reviews #°3818
#  - Sentiment: neutral
#  - News Headline: The deal includes all rental equipment and related merchandise , the rental contract of the depot and two employees , the company said .
#
# Reviews #°3284
#  - Sentiment: neutral
#  - News Headline: The medium-term operative targets of the company remain unchanged .
#
# Reviews #°4600
#  - Sentiment: negative
#  - News Headline: UPM said the move will lower net profit by  x20ac 385 million US$ 520 million in the second quarter , mainly due to impairment charges .

# %% [markdown]
# EDA

# %%
# Configure the plot size
plt.figure(figsize = (15,8))

sns.set(style='darkgrid')
    
# Increase information on the figure
sns.set(font_scale=1.3)
sns.countplot(x='sentiment', data = financial_data)
plt.title('News Sentiment Distribution')
plt.xlabel('News Polarity')
plt.ylabel('Number of News')
# Out:
# Text(0, 0.5, 'Number of News')

# %%
def get_headlines_len(df):
    
    headlines_sequence_lengths = []
    
    print("Encoding in progress...")
    for headline in tqdm(df.headline):
        encoded_headline = finbert_tokenizer.encode(headline, 
                                         add_special_tokens = True)
        
        # record the length of the encoded review
        headlines_sequence_lengths.append(len(encoded_headline))
    print("End of Task.")
    
    return headlines_sequence_lengths

# %% [markdown]
# **Data Preparation**

# %%
def encode_sentiments_values(df):
    
    possible_sentiments = df.sentiment.unique()
    sentiment_dict = {}
    
    for index, possible_sentiment in enumerate(possible_sentiments):
        sentiment_dict[possible_sentiment] = index
    
    # Encode all the sentiment values
    df['label'] = df.sentiment.replace(sentiment_dict)
    
    return df, sentiment_dict

# %%
financial_data.head()
# Out:
#   sentiment                                           headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
# Encode the sentiment column
financial_data, sentiment_dict = encode_sentiments_values(financial_data)

financial_data.head()
# Out:
#   sentiment                                           headline  label
# 0   neutral  According to Gran , the company has no plans t...      0
# 1   neutral  Technopolis plans to develop in stages an area...      0
# 2  negative  The international electronic industry company ...      1
# 3  positive  With the new production plant the company woul...      2
# 4  positive  According to the company 's updated strategy f...      2

# %%
# Create training and validation data
X_train, X_val, y_train, y_val = train_test_split(financial_data.index.values, 
                                                  financial_data.label.values, 
                                                  test_size = 0.15, 
                                                  random_state = 2022,
                                                  stratify = financial_data.label.values)

# %%
# Create the data type columns
financial_data.loc[X_train, 'data_type'] = 'train'
financial_data.loc[X_val, 'data_type'] = 'val'

# Vizualiez the number of sentiment occurence on each type of data
financial_data.groupby(['sentiment', 'label', 'data_type']).count()
# Out:
#                            headline
# sentiment label data_type
# negative  1     train           513
#                 val              91
# neutral   0     train          2447
#                 val             432
# positive  2     train          1159
#                 val             204

# %%
# Get the FinBERT Tokenizer
finbert_tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert", 
                                          do_lower_case=True)

# Encode the Training and Validation Data
encoded_data_train = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='train'].headline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)

encoded_data_val = finbert_tokenizer.batch_encode_plus(
    financial_data[financial_data.data_type=='val'].headline.values, 
    return_tensors='pt',
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=150 # the maximum lenght observed in the headlines
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(financial_data[financial_data.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
sentiments_val = torch.tensor(financial_data[financial_data.data_type=='val'].label.values)


dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, sentiments_val)
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
len(sentiment_dict)
# Out:
# 3

# %%
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)
# Out:
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]

# %%
headlines_sequence_lengths = get_headlines_len(financial_data)
# Out:
# Encoding in progress...
# 100%|██████████| 4846/4846 [00:03<00:00, 1287.42it/s]
# End of Task.

# %%
'''
# Show the reviews distribution 
The overall implementation of this function is in my notebook at end of the article
'''
show_headline_distribution(headlines_sequence_lengths)
# Out:
# Maximum Sequence Length is 150

# %%
batch_size = 5

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)

epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in sentiment_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
# %%time
seed_val = 2022
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)


def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals


for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_finBERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/824 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/824 [00:01<?, ?it/s, training_loss=1.019]
# Epoch 1:   0%|          | 1/824 [00:01<18:32,  1.35s/it, training_loss=1.019]
# Epoch 1:   0%|          | 1/824 [00:02<18:32,  1.35s/it, training_loss=0.803]
# Epoch 1:   0%|          | 2/824 [00:02<18:41,  1.36s/it, training_loss=0.803]
# Epoch 1:   0%|          | 2/824 [00:03<18:41,  1.36s/it, training_loss=0.530]
# Epoch 1:   0%|          | 3/824 [00:03<17:50,  1.30s/it, training_loss=0.530]
# Epoch 1:   0%|          | 3/824 [00:05<17:50,  1.30s/it, training_loss=0.441]
# Epoch 1:   0%|          | 4/824 [00:05<17:33,  1.28s/it, training_loss=0.441]
# Epoch 1:   0%|          | 4/824 [00:06<17:33,  1.28s/it, training_loss=0.391]
# Epoch 1:   1%|          | 5/824 [00:06<17:00,  1.25s/it, training_loss=0.391]
# Epoch 1:   1%|          | 5/824 [00:07<17:00,  1.25s/it, training_loss=0.836]
# Epoch 1:   1%|          | 6/824 [00:07<16:41,  1.22s/it, training_loss=0.836]
# Epoch 1:   1%|          | 6/824 [00:08<16:41,  1.22s/it, training_loss=0.435]
# Epoch 1:   1%|          | 7/824 [00:08<16:41,  1.23s/it, training_loss=0.435]
# Epoch 1:   1%|          | 7/824 [00:09<16:41,  1.23s/it, training_loss=0.319]
# Epoch 1:   1%|          | 8/824 [00:10<16:33,  1.22s/it, training_loss=0.319]
# Epoch 1:   1%|          | 8/824 [00:11<16:33,  1.22s/it, training_loss=0.403]
# Epoch 1:   1%|          | 9/824 [00:11<16:27,  1.21s/it, training_loss=0.403]
# Epoch 1:   1%|          | 9/824 [00:12<16:27,  1.21s/it, training_loss=0.367]
# Epoch 1:   1%|          | 10/824 [00:12<16:19,  1.20s/it, training_loss=0.367]
# Epoch 1:   1%|          | 10/824 [00:13<16:19,  1.20s/it, training_loss=0.332]
# Epoch 1:   1%|▏         | 11/824 [00:13<16:18,  1.20s/it, training_loss=0.332]
# Epoch 1:   1%|▏         | 11/824 [00:14<16:18,  1.20s/it, training_loss=0.232]
# Epoch 1:   1%|▏         | 12/824 [00:14<16:21,  1.21s/it, training_loss=0.232]
# Epoch 1:   1%|▏         | 12/824 [00:16<16:21,  1.21s/it, training_loss=0.064]
# Epoch 1:   2%|▏         | 13/824 [00:16<16:17,  1.20s/it, training_loss=0.064]
# Epoch 1:   2%|▏         | 13/824 [00:17<16:17,  1.20s/it, training_loss=0.146]
# Epoch 1:   2%|▏         | 14/824 [00:17<16:10,  1.20s/it, training_loss=0.146]
# Epoch 1:   2%|▏         | 14/824 [00:18<16:10,  1.20s/it, training_loss=0.554]
# Epoch 1:   2%|▏         | 15/824 [00:18<16:04,  1.19s/it, training_loss=0.554]
# Epoch 1:   2%|▏         | 15/824 [00:19<16:04,  1.19s/it, training_loss=0.243]
# Epoch 1:   2%|▏         | 16/824 [00:19<16:09,  1.20s/it, training_loss=0.243]
# Epoch 1:   2%|▏         | 16/824 [00:20<16:09,  1.20s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 17/824 [00:20<16:03,  1.19s/it, training_loss=0.259]
# Epoch 1:   2%|▏         | 17/824 [00:21<16:03,  1.19s/it, training_loss=0.514]
# Epoch 1:   2%|▏         | 18/824 [00:21<16:07,  1.20s/it, training_loss=0.514]
# Epoch 1:   2%|▏         | 18/824 [00:23<16:07,  1.20s/it, training_loss=0.599]
# Epoch 1:   2%|▏         | 19/824 [00:23<16:09,  1.20s/it, training_loss=0.599]
# Epoch 1:   2%|▏         | 19/824 [00:24<16:09,  1.20s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 20/824 [00:24<16:14,  1.21s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 20/824 [00:25<16:14,  1.21s/it, training_loss=0.343]
# Epoch 1:   3%|▎         | 21/824 [00:25<16:16,  1.22s/it, training_loss=0.343]
# Epoch 1:   3%|▎         | 21/824 [00:26<16:16,  1.22s/it, training_loss=0.585]
# Epoch 1:   3%|▎         | 22/824 [00:26<16:16,  1.22s/it, training_loss=0.585]
# Epoch 1:   3%|▎         | 22/824 [00:28<16:16,  1.22s/it, training_loss=0.263]
# Epoch 1:   3%|▎         | 23/824 [00:28<16:32,  1.24s/it, training_loss=0.263]
# Epoch 1:   3%|▎         | 23/824 [00:29<16:32,  1.24s/it, training_loss=0.036]
# Epoch 1:   3%|▎         | 24/824 [00:29<16:40,  1.25s/it, training_loss=0.036]
# Epoch 1:   3%|▎         | 24/824 [00:30<16:40,  1.25s/it, training_loss=0.219]
# Epoch 1:   3%|▎         | 25/824 [00:30<16:32,  1.24s/it, training_loss=0.219]
# Epoch 1:   3%|▎         | 25/824 [00:31<16:32,  1.24s/it, training_loss=0.640]
# Epoch 1:   3%|▎         | 26/824 [00:31<16:23,  1.23s/it, training_loss=0.640]
# Epoch 1:   3%|▎         | 26/824 [00:33<16:23,  1.23s/it, training_loss=0.357]
# Epoch 1:   3%|▎         | 27/824 [00:33<16:25,  1.24s/it, training_loss=0.357]
# Epoch 1:   3%|▎         | 27/824 [00:34<16:25,  1.24s/it, training_loss=0.060]
# Epoch 1:   3%|▎         | 28/824 [00:34<16:21,  1.23s/it, training_loss=0.060]
# Epoch 1:   3%|▎         | 28/824 [00:35<16:21,  1.23s/it, training_loss=0.625]
# Epoch 1:   4%|▎         | 29/824 [00:35<16:20,  1.23s/it, training_loss=0.625]
# Epoch 1:   4%|▎         | 29/824 [00:36<16:20,  1.23s/it, training_loss=0.038]
# Epoch 1:   4%|▎         | 30/824 [00:36<16:18,  1.23s/it, training_loss=0.038]
# Epoch 1:   4%|▎         | 30/824 [00:38<16:18,  1.23s/it, training_loss=0.354]
# Epoch 1:   4%|▍         | 31/824 [00:38<16:55,  1.28s/it, training_loss=0.354]
# Epoch 1:   4%|▍         | 31/824 [00:39<16:55,  1.28s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 32/824 [00:39<16:51,  1.28s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 32/824 [00:40<16:51,  1.28s/it, training_loss=0.200]
# Epoch 1:   4%|▍         | 33/824 [00:40<16:54,  1.28s/it, training_loss=0.200]
# Epoch 1:   4%|▍         | 33/824 [00:42<16:54,  1.28s/it, training_loss=0.180]
# Epoch 1:   4%|▍         | 34/824 [00:42<16:53,  1.28s/it, training_loss=0.180]
# Epoch 1:   4%|▍         | 34/824 [00:43<16:53,  1.28s/it, training_loss=0.523]
# Epoch 1:   4%|▍         | 35/824 [00:43<16:47,  1.28s/it, training_loss=0.523]
# Epoch 1:   4%|▍         | 35/824 [00:44<16:47,  1.28s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 36/824 [00:44<16:51,  1.28s/it, training_loss=0.212]
# Epoch 1:   4%|▍         | 36/824 [00:45<16:51,  1.28s/it, training_loss=0.063]
# Epoch 1:   4%|▍         | 37/824 [00:45<16:43,  1.28s/it, training_loss=0.063]
# Epoch 1:   4%|▍         | 37/824 [00:47<16:43,  1.28s/it, training_loss=0.381]
# Epoch 1:   5%|▍         | 38/824 [00:47<16:21,  1.25s/it, training_loss=0.381]
# Epoch 1:   5%|▍         | 38/824 [00:48<16:21,  1.25s/it, training_loss=0.357]
# Epoch 1:   5%|▍         | 39/824 [00:48<16:10,  1.24s/it, training_loss=0.357]
# Epoch 1:   5%|▍         | 39/824 [00:49<16:10,  1.24s/it, training_loss=0.495]
# Epoch 1:   5%|▍         | 40/824 [00:49<15:59,  1.22s/it, training_loss=0.495]
# Epoch 1:   5%|▍         | 40/824 [00:50<15:59,  1.22s/it, training_loss=0.549]
# Epoch 1:   5%|▍         | 41/824 [00:50<15:54,  1.22s/it, training_loss=0.549]
# Epoch 1:   5%|▍         | 41/824 [00:51<15:54,  1.22s/it, training_loss=0.324]
# Epoch 1:   5%|▌         | 42/824 [00:51<15:48,  1.21s/it, training_loss=0.324]
# Epoch 1:   5%|▌         | 42/824 [00:53<15:48,  1.21s/it, training_loss=0.506]
# Epoch 1:   5%|▌         | 43/824 [00:53<16:07,  1.24s/it, training_loss=0.506]
# Epoch 1:   5%|▌         | 43/824 [00:54<16:07,  1.24s/it, training_loss=0.050]
# Epoch 1:   5%|▌         | 44/824 [00:54<16:21,  1.26s/it, training_loss=0.050]
# Epoch 1:   5%|▌         | 44/824 [00:55<16:21,  1.26s/it, training_loss=0.306]
# Epoch 1:   5%|▌         | 45/824 [00:55<16:24,  1.26s/it, training_loss=0.306]
# Epoch 1:   5%|▌         | 45/824 [00:56<16:24,  1.26s/it, training_loss=0.184]
# Epoch 1:   6%|▌         | 46/824 [00:56<16:16,  1.25s/it, training_loss=0.184]
# Epoch 1:   6%|▌         | 46/824 [00:58<16:16,  1.25s/it, training_loss=0.074]
# Epoch 1:   6%|▌         | 47/824 [00:58<16:22,  1.26s/it, training_loss=0.074]
# Epoch 1:   6%|▌         | 47/824 [00:59<16:22,  1.26s/it, training_loss=0.210]
# Epoch 1:   6%|▌         | 48/824 [00:59<16:15,  1.26s/it, training_loss=0.210]
# Epoch 1:   6%|▌         | 48/824 [01:00<16:15,  1.26s/it, training_loss=0.432]
# Epoch 1:   6%|▌         | 49/824 [01:00<16:07,  1.25s/it, training_loss=0.432]
# Epoch 1:   6%|▌         | 49/824 [01:01<16:07,  1.25s/it, training_loss=0.282]
# Epoch 1:   6%|▌         | 50/824 [01:01<16:00,  1.24s/it, training_loss=0.282]
# Epoch 1:   6%|▌         | 50/824 [01:03<16:00,  1.24s/it, training_loss=0.305]
# Epoch 1:   6%|▌         | 51/824 [01:03<15:56,  1.24s/it, training_loss=0.305]
# Epoch 1:   6%|▌         | 51/824 [01:04<15:56,  1.24s/it, training_loss=0.199]
# Epoch 1:   6%|▋         | 52/824 [01:04<15:55,  1.24s/it, training_loss=0.199]
# Epoch 1:   6%|▋         | 52/824 [01:05<15:55,  1.24s/it, training_loss=0.119]
# Epoch 1:   6%|▋         | 53/824 [01:05<15:52,  1.24s/it, training_loss=0.119]
# Epoch 1:   6%|▋         | 53/824 [01:06<15:52,  1.24s/it, training_loss=0.084]
# Epoch 1:   7%|▋         | 54/824 [01:06<15:47,  1.23s/it, training_loss=0.084]
# Epoch 1:   7%|▋         | 54/824 [01:08<15:47,  1.23s/it, training_loss=0.234]
# Epoch 1:   7%|▋         | 55/824 [01:08<15:44,  1.23s/it, training_loss=0.234]
# Epoch 1:   7%|▋         | 55/824 [01:09<15:44,  1.23s/it, training_loss=0.337]
# Epoch 1:   7%|▋         | 56/824 [01:09<15:50,  1.24s/it, training_loss=0.337]
# Epoch 1:   7%|▋         | 56/824 [01:10<15:50,  1.24s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 57/824 [01:10<16:04,  1.26s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 57/824 [01:11<16:04,  1.26s/it, training_loss=0.213]
# Epoch 1:   7%|▋         | 58/824 [01:11<16:04,  1.26s/it, training_loss=0.213]
# Epoch 1:   7%|▋         | 58/824 [01:13<16:04,  1.26s/it, training_loss=0.145]
# Epoch 1:   7%|▋         | 59/824 [01:13<15:51,  1.24s/it, training_loss=0.145]
# Epoch 1:   7%|▋         | 59/824 [01:14<15:51,  1.24s/it, training_loss=0.269]
# Epoch 1:   7%|▋         | 60/824 [01:14<16:03,  1.26s/it, training_loss=0.269]
# Epoch 1:   7%|▋         | 60/824 [01:15<16:03,  1.26s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 61/824 [01:15<16:10,  1.27s/it, training_loss=0.158]
# Epoch 1:   7%|▋         | 61/824 [01:17<16:10,  1.27s/it, training_loss=0.278]
# Epoch 1:   8%|▊         | 62/824 [01:17<16:17,  1.28s/it, training_loss=0.278]
# Epoch 1:   8%|▊         | 62/824 [01:18<16:17,  1.28s/it, training_loss=0.203]
# Epoch 1:   8%|▊         | 63/824 [01:18<16:19,  1.29s/it, training_loss=0.203]
# Epoch 1:   8%|▊         | 63/824 [01:19<16:19,  1.29s/it, training_loss=0.118]
# Epoch 1:   8%|▊         | 64/824 [01:19<16:14,  1.28s/it, training_loss=0.118]
# Epoch 1:   8%|▊         | 64/824 [01:20<16:14,  1.28s/it, training_loss=0.400]
# Epoch 1:   8%|▊         | 65/824 [01:20<16:15,  1.28s/it, training_loss=0.400]
# Epoch 1:   8%|▊         | 65/824 [01:22<16:15,  1.28s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 66/824 [01:22<16:07,  1.28s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 66/824 [01:23<16:07,  1.28s/it, training_loss=0.235]
# Epoch 1:   8%|▊         | 67/824 [01:23<16:02,  1.27s/it, training_loss=0.235]
# Epoch 1:   8%|▊         | 67/824 [01:24<16:02,  1.27s/it, training_loss=0.330]
# Epoch 1:   8%|▊         | 68/824 [01:24<16:03,  1.27s/it, training_loss=0.330]
# Epoch 1:   8%|▊         | 68/824 [01:25<16:03,  1.27s/it, training_loss=0.098]
# Epoch 1:   8%|▊         | 69/824 [01:25<15:56,  1.27s/it, training_loss=0.098]
# Epoch 1:   8%|▊         | 69/824 [01:27<15:56,  1.27s/it, training_loss=0.284]
# Epoch 1:   8%|▊         | 70/824 [01:27<16:04,  1.28s/it, training_loss=0.284]
# Epoch 1:   8%|▊         | 70/824 [01:28<16:04,  1.28s/it, training_loss=0.379]
# Epoch 1:   9%|▊         | 71/824 [01:28<16:05,  1.28s/it, training_loss=0.379]
# Epoch 1:   9%|▊         | 71/824 [01:29<16:05,  1.28s/it, training_loss=0.128]
# Epoch 1:   9%|▊         | 72/824 [01:29<16:08,  1.29s/it, training_loss=0.128]
# Epoch 1:   9%|▊         | 72/824 [01:31<16:08,  1.29s/it, training_loss=0.121]
# Epoch 1:   9%|▉         | 73/824 [01:31<16:10,  1.29s/it, training_loss=0.121]
# Epoch 1:   9%|▉         | 73/824 [01:32<16:10,  1.29s/it, training_loss=0.178]
# Epoch 1:   9%|▉         | 74/824 [01:32<16:13,  1.30s/it, training_loss=0.178]
# Epoch 1:   9%|▉         | 74/824 [01:33<16:13,  1.30s/it, training_loss=0.171]
# Epoch 1:   9%|▉         | 75/824 [01:33<16:12,  1.30s/it, training_loss=0.171]
# Epoch 1:   9%|▉         | 75/824 [01:35<16:12,  1.30s/it, training_loss=0.069]
# Epoch 1:   9%|▉         | 76/824 [01:35<16:09,  1.30s/it, training_loss=0.069]
# Epoch 1:   9%|▉         | 76/824 [01:36<16:09,  1.30s/it, training_loss=0.160]
# Epoch 1:   9%|▉         | 77/824 [01:36<16:00,  1.29s/it, training_loss=0.160]
# Epoch 1:   9%|▉         | 77/824 [01:37<16:00,  1.29s/it, training_loss=0.150]
# Epoch 1:   9%|▉         | 78/824 [01:37<15:53,  1.28s/it, training_loss=0.150]
# Epoch 1:   9%|▉         | 78/824 [01:38<15:53,  1.28s/it, training_loss=0.155]
# Epoch 1:  10%|▉         | 79/824 [01:38<15:40,  1.26s/it, training_loss=0.155]
# Epoch 1:  10%|▉         | 79/824 [01:39<15:40,  1.26s/it, training_loss=0.215]
# Epoch 1:  10%|▉         | 80/824 [01:39<15:26,  1.24s/it, training_loss=0.215]
# Epoch 1:  10%|▉         | 80/824 [01:41<15:26,  1.24s/it, training_loss=0.323]
# Epoch 1:  10%|▉         | 81/824 [01:41<15:18,  1.24s/it, training_loss=0.323]
# Epoch 1:  10%|▉         | 81/824 [01:42<15:18,  1.24s/it, training_loss=0.244]
# Epoch 1:  10%|▉         | 82/824 [01:42<15:08,  1.22s/it, training_loss=0.244]
# Epoch 1:  10%|▉         | 82/824 [01:43<15:08,  1.22s/it, training_loss=0.239]
# Epoch 1:  10%|█         | 83/824 [01:43<15:02,  1.22s/it, training_loss=0.239]
# Epoch 1:  10%|█         | 83/824 [01:44<15:02,  1.22s/it, training_loss=0.336]
# Epoch 1:  10%|█         | 84/824 [01:44<15:04,  1.22s/it, training_loss=0.336]
# Epoch 1:  10%|█         | 84/824 [01:46<15:04,  1.22s/it, training_loss=0.481]
# Epoch 1:  10%|█         | 85/824 [01:46<15:08,  1.23s/it, training_loss=0.481]
# Epoch 1:  10%|█         | 85/824 [01:47<15:08,  1.23s/it, training_loss=0.105]
# Epoch 1:  10%|█         | 86/824 [01:47<14:59,  1.22s/it, training_loss=0.105]
# Epoch 1:  10%|█         | 86/824 [01:48<14:59,  1.22s/it, training_loss=0.250]
# Epoch 1:  11%|█         | 87/824 [01:48<14:53,  1.21s/it, training_loss=0.250]
# Epoch 1:  11%|█         | 87/824 [01:49<14:53,  1.21s/it, training_loss=0.342]
# Epoch 1:  11%|█         | 88/824 [01:49<14:48,  1.21s/it, training_loss=0.342]
# Epoch 1:  11%|█         | 88/824 [01:50<14:48,  1.21s/it, training_loss=0.204]
# Epoch 1:  11%|█         | 89/824 [01:50<14:49,  1.21s/it, training_loss=0.204]
# Epoch 1:  11%|█         | 89/824 [01:52<14:49,  1.21s/it, training_loss=0.159]
# Epoch 1:  11%|█         | 90/824 [01:52<14:49,  1.21s/it, training_loss=0.159]
# Epoch 1:  31%|███▏      | 258/824 [05:16<11:18,  1.20s/it, training_loss=0.237]
# Epoch 1:  31%|███▏      | 259/824 [05:16<11:06,  1.18s/it, training_loss=0.237]
# Epoch 1:  31%|███▏      | 259/824 [05:17<11:06,  1.18s/it, training_loss=0.106]
# Epoch 1:  32%|███▏      | 260/824 [05:17<11:19,  1.21s/it, training_loss=0.106]
# Epoch 1:  32%|███▏      | 260/824 [05:19<11:19,  1.21s/it, training_loss=0.406]
# Epoch 1:  32%|███▏      | 261/824 [05:19<11:27,  1.22s/it, training_loss=0.406]
# Epoch 1:  32%|███▏      | 261/824 [05:20<11:27,  1.22s/it, training_loss=0.021]
# Epoch 1:  32%|███▏      | 262/824 [05:20<11:35,  1.24s/it, training_loss=0.021]
# Epoch 1:  32%|███▏      | 262/824 [05:21<11:35,  1.24s/it, training_loss=0.258]
# Epoch 1:  32%|███▏      | 263/824 [05:21<11:39,  1.25s/it, training_loss=0.258]
# Epoch 1:  32%|███▏      | 263/824 [05:22<11:39,  1.25s/it, training_loss=0.261]
# Epoch 1:  32%|███▏      | 264/824 [05:22<11:39,  1.25s/it, training_loss=0.261]
# Epoch 1:  32%|███▏      | 264/824 [05:24<11:39,  1.25s/it, training_loss=0.081]
# Epoch 1:  32%|███▏      | 265/824 [05:24<11:36,  1.25s/it, training_loss=0.081]
# Epoch 1:  32%|███▏      | 265/824 [05:25<11:36,  1.25s/it, training_loss=0.080]
# Epoch 1:  32%|███▏      | 266/824 [05:25<11:42,  1.26s/it, training_loss=0.080]
# Epoch 1:  32%|███▏      | 266/824 [05:26<11:42,  1.26s/it, training_loss=0.203]
# Epoch 1:  32%|███▏      | 267/824 [05:26<11:27,  1.24s/it, training_loss=0.203]
# Epoch 1:  32%|███▏      | 267/824 [05:27<11:27,  1.24s/it, training_loss=0.092]
# Epoch 1:  33%|███▎      | 268/824 [05:27<11:20,  1.22s/it, training_loss=0.092]
# Epoch 1:  33%|███▎      | 268/824 [05:28<11:20,  1.22s/it, training_loss=0.190]
# Epoch 1:  33%|███▎      | 269/824 [05:28<11:22,  1.23s/it, training_loss=0.190]
# Epoch 1:  33%|███▎      | 269/824 [05:30<11:22,  1.23s/it, training_loss=0.106]
# Epoch 1:  33%|███▎      | 270/824 [05:30<11:22,  1.23s/it, training_loss=0.106]
# Epoch 1:  33%|███▎      | 270/824 [05:31<11:22,  1.23s/it, training_loss=0.272]
# Epoch 1:  33%|███▎      | 271/824 [05:31<11:20,  1.23s/it, training_loss=0.272]
# Epoch 1:  33%|███▎      | 271/824 [05:32<11:20,  1.23s/it, training_loss=0.238]
# Epoch 1:  33%|███▎      | 272/824 [05:32<11:29,  1.25s/it, training_loss=0.238]
# Epoch 1:  33%|███▎      | 272/824 [05:33<11:29,  1.25s/it, training_loss=0.219]
# Epoch 1:  33%|███▎      | 273/824 [05:33<11:32,  1.26s/it, training_loss=0.219]
# Epoch 1:  33%|███▎      | 273/824 [05:35<11:32,  1.26s/it, training_loss=0.171]
# Epoch 1:  33%|███▎      | 274/824 [05:35<11:36,  1.27s/it, training_loss=0.171]
# Epoch 1:  33%|███▎      | 274/824 [05:36<11:36,  1.27s/it, training_loss=0.031]
# Epoch 1:  33%|███▎      | 275/824 [05:36<11:28,  1.25s/it, training_loss=0.031]
# Epoch 1:  35%|███▌      | 291/824 [05:56<10:41,  1.20s/it, training_loss=0.042]
# Epoch 1:  35%|███▌      | 291/824 [05:57<10:41,  1.20s/it, training_loss=0.088]
# Epoch 1:  35%|███▌      | 292/824 [05:57<10:35,  1.19s/it, training_loss=0.088]
# Epoch 1:  35%|███▌      | 292/824 [05:58<10:35,  1.19s/it, training_loss=0.026]
# Epoch 1:  36%|███▌      | 293/824 [05:58<10:35,  1.20s/it, training_loss=0.026]
# Epoch 1:  36%|███▌      | 293/824 [05:59<10:35,  1.20s/it, training_loss=0.155]
# Epoch 1:  36%|███▌      | 294/824 [05:59<10:41,  1.21s/it, training_loss=0.155]
# Epoch 1:  36%|███▌      | 294/824 [06:00<10:41,  1.21s/it, training_loss=0.040]
# Epoch 1:  36%|███▌      | 295/824 [06:00<10:35,  1.20s/it, training_loss=0.040]
# Epoch 1:  36%|███▌      | 295/824 [06:02<10:35,  1.20s/it, training_loss=0.161]
# Epoch 1:  36%|███▌      | 296/824 [06:02<10:30,  1.19s/it, training_loss=0.161]
# Epoch 1:  36%|███▌      | 296/824 [06:03<10:30,  1.19s/it, training_loss=0.030]
# Epoch 1:  36%|███▌      | 297/824 [06:03<10:26,  1.19s/it, training_loss=0.030]
# Epoch 1:  36%|███▌      | 297/824 [06:04<10:26,  1.19s/it, training_loss=0.260]
# Epoch 1:  36%|███▌      | 298/824 [06:04<10:23,  1.19s/it, training_loss=0.260]
# Epoch 1:  36%|███▌      | 298/824 [06:05<10:23,  1.19s/it, training_loss=0.303]
# Epoch 1:  36%|███▋      | 299/824 [06:05<10:20,  1.18s/it, training_loss=0.303]
# Epoch 1:  36%|███▋      | 299/824 [06:06<10:20,  1.18s/it, training_loss=0.076]
# Epoch 1:  36%|███▋      | 300/824 [06:06<10:24,  1.19s/it, training_loss=0.076]
# Epoch 1:  36%|███▋      | 300/824 [06:07<10:24,  1.19s/it, training_loss=0.032]
# ...
# Epoch 3:  88%|████████▊ | 726/824 [14:14<01:56,  1.18s/it, training_loss=0.221]
# Epoch 3:  88%|████████▊ | 727/824 [14:14<01:53,  1.17s/it, training_loss=0.221]
# Epoch 3:  88%|████████▊ | 727/824 [14:15<01:53,  1.17s/it, training_loss=0.065]
# Epoch 3:  88%|████████▊ | 728/824 [14:15<01:52,  1.17s/it, training_loss=0.065]
# Epoch 3:  88%|████████▊ | 728/824 [14:16<01:52,  1.17s/it, training_loss=0.001]
# Epoch 3:  88%|████████▊ | 729/824 [14:16<01:49,  1.16s/it, training_loss=0.001]
# Epoch 3:  88%|████████▊ | 729/824 [14:17<01:49,  1.16s/it, training_loss=0.003]
# Epoch 3:  89%|████████▊ | 730/824 [14:17<01:47,  1.14s/it, training_loss=0.003]
# Epoch 3:  89%|████████▊ | 730/824 [14:18<01:47,  1.14s/it, training_loss=0.001]
# Epoch 3:  89%|████████▊ | 731/824 [14:18<01:46,  1.15s/it, training_loss=0.001]
# Epoch 3:  89%|████████▊ | 731/824 [14:19<01:46,  1.15s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 732/824 [14:19<01:45,  1.14s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 732/824 [14:21<01:45,  1.14s/it, training_loss=0.113]
# Epoch 3:  89%|████████▉ | 733/824 [14:21<01:45,  1.15s/it, training_loss=0.113]
# Epoch 3:  89%|████████▉ | 733/824 [14:22<01:45,  1.15s/it, training_loss=0.000]
# Epoch 3:  89%|████████▉ | 734/824 [14:22<01:45,  1.17s/it, training_loss=0.000]
# Epoch 3:  89%|████████▉ | 734/824 [14:23<01:45,  1.17s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 735/824 [14:23<01:45,  1.19s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 735/824 [14:24<01:45,  1.19s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 736/824 [14:24<01:44,  1.19s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 736/824 [14:25<01:44,  1.19s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 737/824 [14:25<01:43,  1.19s/it, training_loss=0.001]
# Epoch 3:  89%|████████▉ | 737/824 [14:27<01:43,  1.19s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 738/824 [14:27<01:43,  1.20s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 738/824 [14:28<01:43,  1.20s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 739/824 [14:28<01:40,  1.18s/it, training_loss=0.001]
# Epoch 3:  90%|████████▉ | 739/824 [14:29<01:40,  1.18s/it, training_loss=0.004]
# Epoch 3:  90%|████████▉ | 740/824 [14:29<01:38,  1.17s/it, training_loss=0.004]
# Epoch 3:  90%|████████▉ | 740/824 [14:30<01:38,  1.17s/it, training_loss=0.000]
# Epoch 3:  90%|████████▉ | 741/824 [14:30<01:36,  1.16s/it, training_loss=0.000]
# Epoch 3:  90%|████████▉ | 741/824 [14:31<01:36,  1.16s/it, training_loss=0.000]
# Epoch 3:  90%|█████████ | 742/824 [14:31<01:35,  1.17s/it, training_loss=0.000]
# Epoch 3:  90%|█████████ | 742/824 [14:32<01:35,  1.17s/it, training_loss=0.153]
# Epoch 3:  90%|█████████ | 743/824 [14:32<01:34,  1.17s/it, training_loss=0.153]
# Epoch 3:  90%|█████████ | 743/824 [14:34<01:34,  1.17s/it, training_loss=0.464]
# Epoch 3:  90%|█████████ | 744/824 [14:34<01:35,  1.19s/it, training_loss=0.464]
# Epoch 3:  90%|█████████ | 744/824 [14:35<01:35,  1.19s/it, training_loss=0.027]
# Epoch 3:  90%|█████████ | 745/824 [14:35<01:35,  1.21s/it, training_loss=0.027]
# Epoch 3:  90%|█████████ | 745/824 [14:36<01:35,  1.21s/it, training_loss=0.006]
# Epoch 3:  91%|█████████ | 746/824 [14:36<01:34,  1.21s/it, training_loss=0.006]
# Epoch 3:  91%|█████████ | 746/824 [14:37<01:34,  1.21s/it, training_loss=0.413]
# Epoch 3:  91%|█████████ | 747/824 [14:37<01:34,  1.23s/it, training_loss=0.413]
# Epoch 3:  91%|█████████ | 747/824 [14:39<01:34,  1.23s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 748/824 [14:39<01:32,  1.22s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 748/824 [14:40<01:32,  1.22s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 749/824 [14:40<01:30,  1.20s/it, training_loss=0.001]
# Epoch 3:  91%|█████████ | 749/824 [14:41<01:30,  1.20s/it, training_loss=0.189]
# Epoch 3:  91%|█████████ | 750/824 [14:41<01:28,  1.19s/it, training_loss=0.189]
# Epoch 3:  91%|█████████ | 750/824 [14:42<01:28,  1.19s/it, training_loss=0.402]
# Epoch 3:  91%|█████████ | 751/824 [14:42<01:27,  1.20s/it, training_loss=0.402]
# Epoch 3:  91%|█████████ | 751/824 [14:43<01:27,  1.20s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 752/824 [14:43<01:25,  1.19s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 752/824 [14:44<01:25,  1.19s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 753/824 [14:44<01:24,  1.19s/it, training_loss=0.001]
# Epoch 3:  91%|█████████▏| 753/824 [14:46<01:24,  1.19s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 754/824 [14:46<01:22,  1.18s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 754/824 [14:47<01:22,  1.18s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 755/824 [14:47<01:21,  1.17s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 755/824 [14:48<01:21,  1.17s/it, training_loss=0.338]
# Epoch 3:  92%|█████████▏| 756/824 [14:48<01:19,  1.18s/it, training_loss=0.338]
# Epoch 3:  92%|█████████▏| 756/824 [14:49<01:19,  1.18s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 757/824 [14:49<01:18,  1.17s/it, training_loss=0.088]
# Epoch 3:  92%|█████████▏| 757/824 [14:50<01:18,  1.17s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 758/824 [14:50<01:17,  1.17s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 758/824 [14:51<01:17,  1.17s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 759/824 [14:51<01:16,  1.17s/it, training_loss=0.002]
# Epoch 3:  92%|█████████▏| 759/824 [14:53<01:16,  1.17s/it, training_loss=0.400]
# Epoch 3:  92%|█████████▏| 760/824 [14:53<01:15,  1.17s/it, training_loss=0.400]
# Epoch 3:  92%|█████████▏| 760/824 [14:54<01:15,  1.17s/it, training_loss=0.405]
# Epoch 3:  92%|█████████▏| 761/824 [14:54<01:14,  1.18s/it, training_loss=0.405]
# Epoch 3:  92%|█████████▏| 761/824 [14:55<01:14,  1.18s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 762/824 [14:55<01:12,  1.17s/it, training_loss=0.001]
# Epoch 3:  92%|█████████▏| 762/824 [14:56<01:12,  1.17s/it, training_loss=0.011]
# Epoch 3:  93%|█████████▎| 763/824 [14:56<01:10,  1.16s/it, training_loss=0.011]
# Epoch 3:  93%|█████████▎| 763/824 [14:57<01:10,  1.16s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 764/824 [14:57<01:10,  1.17s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 764/824 [14:58<01:10,  1.17s/it, training_loss=0.010]
# Epoch 3:  93%|█████████▎| 765/824 [14:58<01:09,  1.17s/it, training_loss=0.010]
# Epoch 3:  93%|█████████▎| 765/824 [15:00<01:09,  1.17s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 766/824 [15:00<01:08,  1.18s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 766/824 [15:01<01:08,  1.18s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 767/824 [15:01<01:07,  1.19s/it, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 767/824 [15:02<01:07,  1.19s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 768/824 [15:02<01:05,  1.17s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 768/824 [15:03<01:05,  1.17s/it, training_loss=0.007]
# Epoch 3:  93%|█████████▎| 769/824 [15:03<01:03,  1.15s/it, training_loss=0.007]
# Epoch 3:  93%|█████████▎| 769/824 [15:04<01:03,  1.15s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 770/824 [15:04<01:02,  1.15s/it, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 770/824 [15:05<01:02,  1.15s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 771/824 [15:05<01:01,  1.17s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 771/824 [15:07<01:01,  1.17s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 772/824 [15:07<01:01,  1.17s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▎| 772/824 [15:08<01:01,  1.17s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 773/824 [15:08<01:00,  1.19s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 773/824 [15:09<01:00,  1.19s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 774/824 [15:09<01:00,  1.21s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 774/824 [15:10<01:00,  1.21s/it, training_loss=0.004]
# Epoch 3:  94%|█████████▍| 775/824 [15:10<00:59,  1.21s/it, training_loss=0.004]
# Epoch 3:  94%|█████████▍| 775/824 [15:12<00:59,  1.21s/it, training_loss=0.128]
# Epoch 3:  94%|█████████▍| 776/824 [15:12<00:57,  1.20s/it, training_loss=0.128]
# Epoch 3:  94%|█████████▍| 776/824 [15:13<00:57,  1.20s/it, training_loss=0.270]
# Epoch 3:  94%|█████████▍| 777/824 [15:13<00:56,  1.19s/it, training_loss=0.270]
# Epoch 3:  94%|█████████▍| 777/824 [15:14<00:56,  1.19s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 778/824 [15:14<00:54,  1.18s/it, training_loss=0.001]
# Epoch 3:  94%|█████████▍| 778/824 [15:15<00:54,  1.18s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▍| 779/824 [15:15<00:52,  1.18s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▍| 779/824 [15:16<00:52,  1.18s/it, training_loss=0.002]
# Epoch 3:  95%|█████████▍| 780/824 [15:16<00:51,  1.17s/it, training_loss=0.002]
# Epoch 3:  95%|█████████▍| 780/824 [15:17<00:51,  1.17s/it, training_loss=0.396]
# Epoch 3:  95%|█████████▍| 781/824 [15:17<00:50,  1.17s/it, training_loss=0.396]
# Epoch 3:  95%|█████████▍| 781/824 [15:19<00:50,  1.17s/it, training_loss=0.006]
# Epoch 3:  95%|█████████▍| 782/824 [15:19<00:49,  1.18s/it, training_loss=0.006]
# Epoch 3:  95%|█████████▍| 782/824 [15:20<00:49,  1.18s/it, training_loss=0.003]
# Epoch 3:  95%|█████████▌| 783/824 [15:20<00:48,  1.17s/it, training_loss=0.003]
# Epoch 3:  95%|█████████▌| 783/824 [15:21<00:48,  1.17s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 784/824 [15:21<00:47,  1.18s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 784/824 [15:22<00:47,  1.18s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 785/824 [15:22<00:45,  1.16s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 785/824 [15:23<00:45,  1.16s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 786/824 [15:23<00:44,  1.17s/it, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 786/824 [15:24<00:44,  1.17s/it, training_loss=0.011]
# Epoch 3:  96%|█████████▌| 787/824 [15:24<00:43,  1.18s/it, training_loss=0.011]
# Epoch 3:  96%|█████████▌| 787/824 [15:26<00:43,  1.18s/it, training_loss=0.039]
# Epoch 3:  96%|█████████▌| 788/824 [15:26<00:42,  1.18s/it, training_loss=0.039]
# Epoch 3:  96%|█████████▌| 788/824 [15:27<00:42,  1.18s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 789/824 [15:27<00:40,  1.16s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 789/824 [15:28<00:40,  1.16s/it, training_loss=0.004]
# Epoch 3:  96%|█████████▌| 790/824 [15:28<00:40,  1.18s/it, training_loss=0.004]
# Epoch 3:  96%|█████████▌| 790/824 [15:29<00:40,  1.18s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 791/824 [15:29<00:38,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 791/824 [15:30<00:38,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 792/824 [15:30<00:37,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 792/824 [15:31<00:37,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 793/824 [15:31<00:36,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▌| 793/824 [15:33<00:36,  1.17s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 794/824 [15:33<00:34,  1.16s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 794/824 [15:34<00:34,  1.16s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 795/824 [15:34<00:33,  1.16s/it, training_loss=0.001]
# Epoch 3:  96%|█████████▋| 795/824 [15:35<00:33,  1.16s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 796/824 [15:35<00:32,  1.16s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 796/824 [15:36<00:32,  1.16s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 797/824 [15:36<00:31,  1.17s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 797/824 [15:37<00:31,  1.17s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 798/824 [15:37<00:30,  1.16s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 798/824 [15:38<00:30,  1.16s/it, training_loss=0.267]
# Epoch 3:  97%|█████████▋| 799/824 [15:38<00:29,  1.17s/it, training_loss=0.267]
# Epoch 3:  97%|█████████▋| 799/824 [15:40<00:29,  1.17s/it, training_loss=0.400]
# Epoch 3:  97%|█████████▋| 800/824 [15:40<00:28,  1.17s/it, training_loss=0.400]
# Epoch 3:  97%|█████████▋| 800/824 [15:41<00:28,  1.17s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 801/824 [15:41<00:27,  1.19s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 801/824 [15:42<00:27,  1.19s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 802/824 [15:42<00:26,  1.18s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 802/824 [15:43<00:26,  1.18s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 803/824 [15:43<00:24,  1.17s/it, training_loss=0.001]
# Epoch 3:  97%|█████████▋| 803/824 [15:44<00:24,  1.17s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 804/824 [15:44<00:23,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 804/824 [15:45<00:23,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 805/824 [15:45<00:21,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 805/824 [15:47<00:21,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 806/824 [15:47<00:20,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 806/824 [15:48<00:20,  1.16s/it, training_loss=0.007]
# Epoch 3:  98%|█████████▊| 807/824 [15:48<00:19,  1.15s/it, training_loss=0.007]
# Epoch 3:  98%|█████████▊| 807/824 [15:49<00:19,  1.15s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 808/824 [15:49<00:18,  1.14s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 808/824 [15:50<00:18,  1.14s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 809/824 [15:50<00:17,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 809/824 [15:51<00:17,  1.16s/it, training_loss=0.006]
# Epoch 3:  98%|█████████▊| 810/824 [15:51<00:16,  1.16s/it, training_loss=0.006]
# Epoch 3:  98%|█████████▊| 810/824 [15:52<00:16,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 811/824 [15:52<00:15,  1.16s/it, training_loss=0.001]
# Epoch 3:  98%|█████████▊| 811/824 [15:53<00:15,  1.16s/it, training_loss=0.003]
# Epoch 3:  99%|█████████▊| 812/824 [15:53<00:13,  1.16s/it, training_loss=0.003]
# Epoch 3:  99%|█████████▊| 812/824 [15:55<00:13,  1.16s/it, training_loss=0.400]
# Epoch 3:  99%|█████████▊| 813/824 [15:55<00:12,  1.17s/it, training_loss=0.400]
# Epoch 3:  99%|█████████▊| 813/824 [15:56<00:12,  1.17s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 814/824 [15:56<00:11,  1.20s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 814/824 [15:57<00:11,  1.20s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 815/824 [15:57<00:10,  1.19s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 815/824 [15:58<00:10,  1.19s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 816/824 [15:58<00:09,  1.18s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 816/824 [15:59<00:09,  1.18s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 817/824 [15:59<00:08,  1.18s/it, training_loss=0.033]
# Epoch 3:  99%|█████████▉| 817/824 [16:01<00:08,  1.18s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 818/824 [16:01<00:07,  1.18s/it, training_loss=0.001]
# Epoch 3:  99%|█████████▉| 818/824 [16:02<00:07,  1.18s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 819/824 [16:02<00:05,  1.16s/it, training_loss=0.002]
# Epoch 3:  99%|█████████▉| 819/824 [16:03<00:05,  1.16s/it, training_loss=0.006]
# Epoch 3: 100%|█████████▉| 820/824 [16:03<00:04,  1.15s/it, training_loss=0.006]
# Epoch 3: 100%|█████████▉| 820/824 [16:04<00:04,  1.15s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 821/824 [16:04<00:03,  1.15s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 821/824 [16:05<00:03,  1.15s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 822/824 [16:05<00:02,  1.14s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 822/824 [16:06<00:02,  1.14s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 823/824 [16:06<00:01,  1.15s/it, training_loss=0.001]
# Epoch 3: 100%|█████████▉| 823/824 [16:07<00:01,  1.15s/it, training_loss=0.001]
# Epoch 3: 100%|██████████| 824/824 [16:07<00:00,  1.12s/it, training_loss=0.001]
#  67%|██████▋   | 2/3 [51:02<17:24, 1044.32s/it]
# Epoch 3
# Training loss: 0.15098944223286398
# 100%|██████████| 3/3 [51:56<00:00, 1038.88s/it]
# Validation loss: 0.538357858375442
# F1 Score (Weighted): 0.871166775606992
# CPU times: user 16h 55min 52s, sys: 17min 16s, total: 17h 13min 8s
# Wall time: 51min 56s

# %%
# Load the best model & Make Predictions
# %%time
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert",
                                                          num_labels=len(sentiment_dict),
                                                          output_attentions=False,
                                                          output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('finetuned_finBERT_epoch_1.model', 
                                 map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)

accuracy_per_class(predictions, true_vals)
# Out:
# Class: neutral
# Accuracy: 395/432
#
# Class: negative
# Accuracy: 73/91
#
# Class: positive
# Accuracy: 160/204
#
# CPU times: user 11min 34s, sys: 3.86 s, total: 11min 38s
# Wall time: 36.4 s
